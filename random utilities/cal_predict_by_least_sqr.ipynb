# %%
import fcntl
import os
import platform
from tkinter import Tk
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import scipy.stats as stats
from sklearn.cluster import KMeans

import sys
sys.path.insert(0, os.path.abspath('.'))
from tools import Sim_Parameters, Train_Parameters, create_dataset, RMSELoss, train_val_test, test_epoch, simulator, ballsINTObins, load_data, NoisyDataset

# %%
def solve_for_B(A, C):
    # Calculate the Moore-Penrose pseudoinverse of matrix A
    A_pseudo_inv = np.linalg.pinv(A)
    
    # Calculate matrix B
    B = np.dot(A_pseudo_inv, C)
    
    return B


substance_ind_list = [0, 1, 2, 3]
substance_ind_list.sort()

basis_func_ind_list = [0, 1, 4, 6]
# basis_func_ind_list = [0, 1, 2, 3, 4]
basis_func_ind_list.sort()

temp_K_list = np.asarray([293.15])
temp_K_list.sort()


air_trans, basis_funcs, spectra, substances_emit = load_data(air_trans_file='./data/Test 3 - 4 White Powers/Air transmittance.xlsx',
                                                             basis_func_file='./data/Test 3 - 4 White Powers/Basis functions_4-20um.xlsx',
                                                             spectra_file='./data/Test 3 - 4 White Powers/white_powders_spectra.xlsx', 
                                                             substances_emit_file='./data/Test 3 - 4 White Powers/white_powders.xlsx',)


substance_names = np.array(pd.read_excel('./data/Test 3 - 4 White Powers/white_powders_names.xlsx', header=None))

b_f_comb = [0, 1, 2]
comb = b_f_comb
temp_K = 293.15

sim_params = Sim_Parameters(air_trans=air_trans,
                            air_RI=1,
                            atm_dist_ratio=0.11,
                            basis_funcs=basis_funcs,
                            basis_func_comb=comb,
                            substance_ind_list=substance_ind_list,
                            spectra=spectra,
                            substances_emit=substances_emit,
                            temp_K=temp_K)

dataset = create_dataset(sim_params)

# %%
sensor_output_list = []

for idx in substance_ind_list:
    sub_signal = substances_emit[:, idx]
    sub_signal = np.expand_dims(sub_signal, 1)
    
    out = simulator(sim_params, sub_signal)  # Apply simulator() function to the column
    sensor_output_list.append(out)

sensor_output_list = np.asarray(sensor_output_list).transpose()
print(sensor_output_list.shape)
# Out:
# (3, 4)

# %%
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

torch.manual_seed(28)
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# test_noise_perc_list = [0, 0.01, 0.03, 0.05, 0.1, 0.2, 0.4, 1, 2]
test_noise_perc_list = [i * 0.05 for i in range(41)]

# %%
results = []

for test_noise_perc in test_noise_perc_list:
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
    if test_noise_perc != 0:
        test_dataset = NoisyDataset(test_dataset, test_noise_perc)


    dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

    loss_list = []
    targ_list = []
    pred_list = []

    

    for batch_idx, (x, y) in enumerate(dataloader):
        print(batch_idx)
        print('x - C - mixture - Norm', x)
        print('y - B - ratio', y)

        print('A - shape', sensor_output_list.shape)
        print('B - shape', y.numpy().transpose().shape)
        print('C - shape', x.numpy().transpose().shape)

        X = np.matmul(sensor_output_list, y.numpy().transpose())
        print('Cal C\n', X.transpose())
        print('Cal C - shape', X.shape)
        print('C original', x.numpy())

        Cal_B_by_Cal_C = solve_for_B(sensor_output_list, X)
        print('Cal B by Cal C\n', Cal_B_by_Cal_C)

        # prediction = solve_for_B(sensor_output_list, x.numpy().transpose())
        prediction = np.linalg.lstsq(sensor_output_list, x.numpy().transpose(), rcond=None)[0]
        print('pred', prediction.transpose())
        print('sum of pred', np.sum(prediction))
        normalized_prediction = prediction / np.sum(prediction)
        prediction = normalized_prediction
        print('pred', prediction.transpose())
        print('sum of pred', np.sum(prediction))

        criterion = nn.L1Loss()

        loss = criterion(torch.from_numpy(prediction.transpose()), y)
        print('loss', loss)
        loss_list.append(loss.numpy())
        targ_list.append(np.squeeze(y.numpy()))
        pred_list.append(np.squeeze(prediction))

    avg_loss = np.mean(loss_list)
    targ_list = np.asarray(targ_list)
    pred_list = np.asarray(pred_list)
    diff_list = pred_list - targ_list

    print('diff_list', diff_list)


    row = {
        'Temperature_K': temp_K,
        'Substance Number': len(substance_ind_list),
        'Substance Comb': tuple(substance_ind_list),
        'Basis Function Number': len(comb),
        'Comb of Basis Functions': comb,
        'Train Noise Max Percentage': 0,
        'Test Noise Max Percentage': test_noise_perc,
        'L1Loss': avg_loss
    }



    perc95_interval = []
    for i, sub_ind in enumerate(substance_ind_list):

        data = diff_list[:, i]
        # params = stats.norm.fit(data)
        # data_mean, data_std = params
        ae, loce, scalee = stats.skewnorm.fit(data)
        
        # Create a skewed normal distribution object
        dist = stats.skewnorm(ae, loce, scalee)


        for confidence_perc in (0.68, 0.95, 0.997):
            # Calculate the quantiles for a specific percentage
            lower_quantile = dist.ppf(0.5-confidence_perc/2)  # Lower quantile covering % of the data
            upper_quantile = dist.ppf(0.5+confidence_perc/2)  # Upper quantile covering % of the data

            if confidence_perc == 0.95:
                perc95_interval.append(upper_quantile - lower_quantile)

    perc95_avg = np.mean(perc95_interval)
    row[f'AVG skewnorm 95% interval range'] = perc95_avg


    # Append the row to the results list
    results.append(row)
# Create a pandas DataFrame from the results list
df = pd.DataFrame(results)



# df.to_csv('.csv', index=False)

output_file_name = 'loss_test_least_sqr.csv'
# Check if the file "loss.pkl" already exists
if os.path.isfile(output_file_name):

    # If the file exists, load the existing DataFrame from the file
    df_existing = pd.read_csv(output_file_name)

    # Open the file in binary mode
    with open(output_file_name, 'w') as f:
        while True:
            try:
                # Get a lock on the file
                fcntl.flock(f, fcntl.LOCK_EX | fcntl.LOCK_NB)
                break
            except IOError:
                # Lock is held by another process, wait and try again
                time.sleep(1)

        # Merge df to df_existing, and if there's duplicates, keep the new values from df
        df = pd.concat([df, df_existing]).drop_duplicates(
            subset=['Temperature_K', 'Substance Number', 'Substance Comb', 'Basis Function Number', 
                    'Comb of Basis Functions', 'Train Noise Max Percentage', 'Test Noise Max Percentage'], keep='first')
        df = df.sort_values(by=list(df.columns))
        print(df)

        # Save the DataFrame to a CSV file "loss.csv"
        df.to_csv(output_file_name, index=False)

        # Release the lock on the file
        fcntl.flock(f, fcntl.LOCK_UN)
else:
    # Save the DataFrame to a CSV file "loss.csv"
    df.to_csv(output_file_name, index=False)
# Out:
# 0
# x - C - mixture - Norm tensor([[14.2358, 15.1640, 15.3628]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.3000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.23580247 15.16403458 15.36281698]]
# Cal C - shape (3, 1)
# C original [[14.235802 15.164034 15.362817]]
# Cal B by Cal C
#  [[ 0.10995088]
#  [-0.00308591]
#  [ 0.28046611]
#  [ 0.60720512]]
# pred [[ 0.1099506  -0.00308601  0.28046605  0.60720531]]
# sum of pred 0.9945359565005006
# pred [[ 0.11055468 -0.00310296  0.28200695  0.61054133]]
# sum of pred 1.0
# loss tensor(0.0105, dtype=torch.float64)
# 1
# x - C - mixture - Norm tensor([[12.8861, 13.4344, 13.4347]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.1000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.88609012 13.43440055 13.43465458]]
# Cal C - shape (3, 1)
# C original [[12.886089 13.4344   13.434654]]
# Cal B by Cal C
#  [[0.03017063]
#  [0.59064367]
#  [0.04077403]
#  [0.32184554]]
# pred [[0.03017016 0.59064412 0.04077375 0.32184561]]
# sum of pred 0.983433644986849
# pred [[0.03067839 0.60059377 0.0414606  0.32726724]]
# sum of pred 1.0
# loss tensor(0.0293, dtype=torch.float64)
# 2
# x - C - mixture - Norm tensor([[12.0875, 12.5528, 12.3580]])
# y - B - ratio tensor([[0.1000, 0.6000, 0.1000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.08749135 12.55276316 12.35798896]]
# Cal C - shape (3, 1)
# C original [[12.087491 12.552763 12.357988]]
# Cal B by Cal C
#  [[0.12512977]
#  [0.59220691]
#  [0.05066941]
#  [0.21819562]]
# pred [[0.12513015 0.5922064  0.05066967 0.21819558]]
# sum of pred 0.9862018021631027
# pred [[0.12688087 0.60049211 0.0513786  0.22124841]]
# sum of pred 1.0
# loss tensor(0.0243, dtype=torch.float64)
# 3
# x - C - mixture - Norm tensor([[12.0183, 12.7059, 12.5065]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.4000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.01828381 12.70594115 12.50646261]]
# Cal C - shape (3, 1)
# C original [[12.018284 12.705941 12.506462]]
# Cal B by Cal C
#  [[0.27289171]
#  [0.07739521]
#  [0.2569111 ]
#  [0.35277843]]
# pred [[0.27289209 0.07739499 0.25691127 0.35277828]]
# sum of pred 0.9599766286577469
# pred [[0.28426951 0.08062174 0.26762243 0.36748632]]
# sum of pred 1.0
# loss tensor(0.0759, dtype=torch.float64)
# 4
# x - C - mixture - Norm tensor([[11.8119, 12.1288, 11.9322]])
# y - B - ratio tensor([[0.0000, 0.9000, 0.0000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.81193392 12.1287642  11.93223995]]
# Cal C - shape (3, 1)
# C original [[11.811934  12.128764  11.9322405]]
# Cal B by Cal C
#  [[ 0.03776007]
#  [ 0.88829002]
#  [-0.0741243 ]
#  [ 0.12734079]]
# pred [[ 0.0377593   0.88829165 -0.07412503  0.12734059]]
# sum of pred 0.979266509660312
# pred [[ 0.03855876  0.90709898 -0.07569444  0.1300367 ]]
# sum of pred 1.0
# loss tensor(0.0378, dtype=torch.float64)
# 5
# x - C - mixture - Norm tensor([[10.7776, 11.3163, 11.1004]])
# y - B - ratio tensor([[0.0000, 0.3000, 0.6000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.77764152 11.3163038  11.10041631]]
# Cal C - shape (3, 1)
# C original [[10.777641 11.316303 11.100416]]
# Cal B by Cal C
#  [[0.21893684]
#  [0.23210449]
#  [0.17021959]
#  [0.25852473]]
# pred [[0.21893636 0.23210535 0.17021918 0.25852465]]
# sum of pred 0.8797855373978438
# pred [[0.24885196 0.26382038 0.19347803 0.29384963]]
# sum of pred 1.0
# loss tensor(0.2214, dtype=torch.float64)
# 6
# x - C - mixture - Norm tensor([[13.4372, 14.2824, 14.2862]])
# y - B - ratio tensor([[0.2000, 0.0000, 0.3000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.43720344 14.28239692 14.28615106]]
# Cal C - shape (3, 1)
# C original [[13.437203 14.282396 14.286151]]
# Cal B by Cal C
#  [[ 0.20491002]
#  [-0.00152267]
#  [ 0.29036148]
#  [ 0.50355518]]
# pred [[ 0.20490935 -0.00152122  0.29036083  0.50355496]]
# sum of pred 0.997303920546133
# pred [[ 0.20546329 -0.00152533  0.29114578  0.50491626]]
# sum of pred 1.0
# loss tensor(0.0052, dtype=torch.float64)
# 7
# x - C - mixture - Norm tensor([[14.4082, 15.2994, 15.5015]])
# y - B - ratio tensor([[0.1000, 0.1000, 0.2000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.40818457 15.29944468 15.50145428]]
# Cal C - shape (3, 1)
# C original [[14.408184 15.299444 15.501453]]
# Cal B by Cal C
#  [[0.07975475]
#  [0.10627835]
#  [0.23974212]
#  [0.58534112]]
# pred [[0.07975505 0.10627804 0.23974229 0.58534104]]
# sum of pred 1.0111164191237083
# pred [[0.07887821 0.1051096  0.23710652 0.57890568]]
# sum of pred 1.0
# loss tensor(0.0211, dtype=torch.float64)
# 8
# x - C - mixture - Norm tensor([[14.3050, 15.0109, 15.2143]])
# y - B - ratio tensor([[0.0000, 0.5000, 0.0000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.30500943 15.01085598 15.21434272]]
# Cal C - shape (3, 1)
# C original [[14.30501  15.010856 15.214343]]
# Cal B by Cal C
#  [[-0.03781107]
#  [ 0.51172577]
#  [ 0.07422441]
#  [ 0.47262229]]
# pred [[-0.03781198  0.5117277   0.07422355  0.47262203]]
# sum of pred 1.0207613014671542
# pred [[-0.03704292  0.50131965  0.07271391  0.46300935]]
# sum of pred 1.0
# loss tensor(0.0370, dtype=torch.float64)
# 9
# x - C - mixture - Norm tensor([[10.1544, 10.5958, 10.2799]])
# y - B - ratio tensor([[0.0000, 0.4000, 0.6000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.15437261 10.59578082 10.27989059]]
# Cal C - shape (3, 1)
# C original [[10.154372 10.59578  10.27989 ]]
# Cal B by Cal C
#  [[0.23782962]
#  [0.32624556]
#  [0.13313241]
#  [0.17220436]]
# pred [[0.23782965 0.32624559 0.1331324  0.17220431]]
# sum of pred 0.8694119404692956
# pred [[0.27355232 0.37524857 0.15312925 0.19806987]]
# sum of pred 1.0
# loss tensor(0.2358, dtype=torch.float64)
# 10
# x - C - mixture - Norm tensor([[13.6096, 14.4178, 14.4248]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.2000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.60958555 14.41780702 14.42478837]]
# Cal C - shape (3, 1)
# C original [[13.609586 14.417807 14.424788]]
# Cal B by Cal C
#  [[0.17471389]
#  [0.10784159]
#  [0.2496375 ]
#  [0.48169119]]
# pred [[0.17471317 0.10784319 0.24963679 0.48169095]]
# sum of pred 1.0138840953923685
# pred [[0.17232065 0.10636639 0.24621827 0.47509469]]
# sum of pred 0.9999999999999998
# loss tensor(0.0263, dtype=torch.float64)
# 11
# x - C - mixture - Norm tensor([[11.2226, 11.8500, 11.5473]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.5000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.22263261 11.85000787 11.54729937]]
# Cal C - shape (3, 1)
# C original [[11.222632 11.850008 11.547299]]
# Cal B by Cal C
#  [[0.32198063]
#  [0.06217202]
#  [0.2605479 ]
#  [0.28832203]]
# pred [[0.32198093 0.06217117 0.26054826 0.28832221]]
# sum of pred 0.9330225691059899
# pred [[0.34509447 0.06663416 0.27925183 0.30901954]]
# sum of pred 1.0
# loss tensor(0.1271, dtype=torch.float64)
# 12
# x - C - mixture - Norm tensor([[10.2340, 10.6787,  9.6270]])
# y - B - ratio tensor([[0.9000, 0.0000, 0.0000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.23396571 10.67873512  9.62698153]]
# Cal C - shape (3, 1)
# C original [[10.233966 10.678736  9.626982]]
# Cal B by Cal C
#  [[ 0.72235723]
#  [ 0.05508961]
#  [ 0.34871873]
#  [-0.02862508]]
# pred [[ 0.72235778  0.05508848  0.34871924 -0.02862492]]
# sum of pred 1.0975405899596156
# pred [[ 0.65816043  0.05019266  0.31772788 -0.02608097]]
# sum of pred 0.9999999999999999
# loss tensor(0.1840, dtype=torch.float64)
# 13
# x - C - mixture - Norm tensor([[10.2369, 10.7044,  9.7445]])
# y - B - ratio tensor([[0.8000, 0.0000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.23691369 10.70443966  9.7444843 ]]
# Cal C - shape (3, 1)
# C original [[10.236914 10.704439  9.744484]]
# Cal B by Cal C
#  [[0.67648704]
#  [0.03830318]
#  [0.34246016]
#  [0.01056845]]
# pred [[0.67648663 0.03830433 0.34245968 0.01056819]]
# sum of pred 1.0678188324698747
# pred [[0.63352192 0.03587156 0.32070953 0.00989699]]
# sum of pred 1.0
# loss tensor(0.1283, dtype=torch.float64)
# 14
# x - C - mixture - Norm tensor([[15.0256, 15.9686, 16.0870]])
# y - B - ratio tensor([[0.3000, 0.0000, 0.0000, 0.7000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[15.02555755 15.96855861 16.08697436]]
# Cal C - shape (3, 1)
# C original [[15.0255575 15.968558  16.086975 ]]
# Cal B by Cal C
#  [[0.15260243]
#  [0.04571015]
#  [0.28934645]
#  [0.5932744 ]]
# pred [[0.15260158 0.04571114 0.28934591 0.59327452]]
# sum of pred 1.0809331447704953
# pred [[0.14117578 0.04228859 0.26768159 0.54885404]]
# sum of pred 1.0
# loss tensor(0.1550, dtype=torch.float64)
# 15
# x - C - mixture - Norm tensor([[9.4472, 9.8999, 9.0203]])
# y - B - ratio tensor([[0.6000, 0.0000, 0.4000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[9.44715811 9.89991508 9.02032631]]
# Cal C - shape (3, 1)
# C original [[9.447158 9.899915 9.020326]]
# Cal B by Cal C
#  [[ 0.6338355 ]
#  [-0.01049288]
#  [ 0.33357981]
#  [ 0.02449912]]
# pred [[ 0.63383566 -0.01049282  0.33357983  0.02449898]]
# sum of pred 0.981421644199879
# pred [[ 0.6458342  -0.01069145  0.33989451  0.02496275]]
# sum of pred 1.0
# loss tensor(0.0354, dtype=torch.float64)
# 16
# x - C - mixture - Norm tensor([[10.9471, 11.4260, 11.1216]])
# y - B - ratio tensor([[0.1000, 0.4000, 0.4000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.94707584 11.42600957 11.12155101]]
# Cal C - shape (3, 1)
# C original [[10.947076 11.426009 11.121551]]
# Cal B by Cal C
#  [[0.23461093]
#  [0.35825519]
#  [0.13575418]
#  [0.19746721]]
# pred [[0.23461071 0.35825607 0.13575383 0.19746695]]
# sum of pred 0.9260875643801721
# pred [[0.25333535 0.38684902 0.14658855 0.21322708]]
# sum of pred 1.0
# loss tensor(0.1333, dtype=torch.float64)
# 17
# x - C - mixture - Norm tensor([[14.4023, 15.2480, 15.2664]])
# y - B - ratio tensor([[0.3000, 0.1000, 0.0000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.40228937 15.24803641 15.26644943]]
# Cal C - shape (3, 1)
# C original [[14.402288 15.248035 15.266449]]
# Cal B by Cal C
#  [[0.17149521]
#  [0.13985122]
#  [0.25225928]
#  [0.50695406]]
# pred [[0.17149487 0.13985138 0.25225913 0.50695418]]
# sum of pred 1.0705595478419467
# pred [[0.16019181 0.13063391 0.23563297 0.47354132]]
# sum of pred 1.0
# loss tensor(0.1331, dtype=torch.float64)
# 18
# x - C - mixture - Norm tensor([[15.2009, 16.1297, 16.3431]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.0000, 0.7000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[15.20088729 16.12967289 16.34311413]]
# Cal C - shape (3, 1)
# C original [[15.200888 16.129673 16.343115]]
# Cal B by Cal C
#  [[0.07653607]
#  [0.13828797]
#  [0.24236389]
#  [0.61060394]]
# pred [[0.07653549 0.13828888 0.24236345 0.61060394]]
# sum of pred 1.0677917552576117
# pred [[0.07167642 0.12950922 0.22697632 0.57183804]]
# sum of pred 1.0
# loss tensor(0.1282, dtype=torch.float64)
# 19
# x - C - mixture - Norm tensor([[11.6396, 11.9934, 11.7936]])
# y - B - ratio tensor([[0.0000, 0.8000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.63955217 11.99335445 11.79360298]]
# Cal C - shape (3, 1)
# C original [[11.639552 11.993354 11.793603]]
# Cal B by Cal C
#  [[ 0.0679562 ]
#  [ 0.7789258 ]
#  [-0.03340033]
#  [ 0.14920478]]
# pred [[ 0.06795548  0.77892725 -0.03340099  0.1492046 ]]
# sum of pred 0.9626863348140758
# pred [[ 0.07058943  0.80911842 -0.03469561  0.15498776]]
# sum of pred 1.0000000000000002
# loss tensor(0.0673, dtype=torch.float64)
# 20
# x - C - mixture - Norm tensor([[12.6357, 13.3751, 13.0920]])
# y - B - ratio tensor([[0.4000, 0.0000, 0.2000, 0.4000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.63565723 13.37505557 13.0919832 ]]
# Cal C - shape (3, 1)
# C original [[12.635657 13.375055 13.091983]]
# Cal B by Cal C
#  [[0.34573939]
#  [0.01682701]
#  [0.30651544]
#  [0.36071173]]
# pred [[0.34573924 0.01682773 0.30651517 0.3607115 ]]
# sum of pred 1.0297936420815064
# pred [[0.33573643 0.01634088 0.29764717 0.35027552]]
# sum of pred 1.0000000000000002
# loss tensor(0.0570, dtype=torch.float64)
# 21
# x - C - mixture - Norm tensor([[13.4402, 14.3081, 14.4037]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.4000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.44015101 14.30810102 14.40365345]]
# Cal C - shape (3, 1)
# C original [[13.440151 14.308101 14.403653]]
# Cal B by Cal C
#  [[ 0.15903979]
#  [-0.0183091 ]
#  [ 0.2841029 ]
#  [ 0.54274871]]
# pred [[ 0.15903944 -0.01830788  0.28410241  0.54274839]]
# sum of pred 0.9675823561870145
# pred [[ 0.16436786 -0.01892127  0.29362091  0.5609325 ]]
# sum of pred 0.9999999999999999
# loss tensor(0.0627, dtype=torch.float64)
# 22
# x - C - mixture - Norm tensor([[11.8488, 12.5962, 12.4853]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.6000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.84884941 12.5962353  12.48532783]]
# Cal C - shape (3, 1)
# C original [[11.848849 12.596235 12.485328]]
# Cal B by Cal C
#  [[ 0.25721762]
#  [-0.04875548]
#  [ 0.29137651]
#  [ 0.41383595]]
# pred [[ 0.25721773 -0.04875573  0.29137662  0.41383598]]
# sum of pred 0.9136746016754184
# pred [[ 0.28152006 -0.05336225  0.31890633  0.45293585]]
# sum of pred 1.0
# loss tensor(0.1672, dtype=torch.float64)
# 23
# x - C - mixture - Norm tensor([[10.2605, 10.9101, 10.6845]])
# y - B - ratio tensor([[0.0000, 0.0000, 0.9000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.26049443 10.91007267 10.68450358]]
# Cal C - shape (3, 1)
# C original [[10.260494 10.910073 10.684504]]
# Cal B by Cal C
#  [[ 0.3095252 ]
#  [-0.09598829]
#  [ 0.29239152]
#  [ 0.32411669]]
# pred [[ 0.30952614 -0.09599038  0.29239244  0.324117  ]]
# sum of pred 0.8300452059897574
# pred [[ 0.37290275 -0.11564476  0.35226087  0.39048115]]
# sum of pred 1.0
# loss tensor(0.3317, dtype=torch.float64)
# 24
# x - C - mixture - Norm tensor([[13.6037, 14.3664, 14.1898]])
# y - B - ratio tensor([[0.4000, 0.1000, 0.0000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.60369028 14.36639867 14.18978346]]
# Cal C - shape (3, 1)
# C original [[13.60369  14.366399 14.189783]]
# Cal B by Cal C
#  [[0.26645435]
#  [0.14141446]
#  [0.26215465]
#  [0.40330412]]
# pred [[0.26645485 0.14141366 0.26215505 0.40330415]]
# sum of pred 1.073327705018201
# pred [[0.24825116 0.13175254 0.24424511 0.37575118]]
# sum of pred 1.0
# loss tensor(0.1380, dtype=torch.float64)
# 25
# x - C - mixture - Norm tensor([[14.1297, 14.8497, 14.9582]])
# y - B - ratio tensor([[0.1000, 0.4000, 0.0000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.1296797  14.84974172 14.95820296]]
# Cal C - shape (3, 1)
# C original [[14.12968  14.849742 14.958203]]
# Cal B by Cal C
#  [[0.03825529]
#  [0.41914795]
#  [0.12120697]
#  [0.45529275]]
# pred [[0.03825535 0.41914745 0.12120715 0.45529293]]
# sum of pred 1.033902884110658
# pred [[0.03700092 0.40540311 0.11723263 0.44036334]]
# sum of pred 0.9999999999999999
# loss tensor(0.0613, dtype=torch.float64)
# 26
# x - C - mixture - Norm tensor([[ 9.9702, 10.3576,  9.6712]])
# y - B - ratio tensor([[0.4000, 0.3000, 0.3000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.97019991 10.35755397  9.67124339]]
# Cal C - shape (3, 1)
# C original [[ 9.9702    10.3575535  9.671243 ]]
# Cal B by Cal C
#  [[0.45150666]
#  [0.28402704]
#  [0.1988907 ]
#  [0.03729422]]
# pred [[0.4515067  0.28402728 0.19889063 0.03729407]]
# sum of pred 0.9717186754284292
# pred [[0.46464754 0.29229373 0.20467923 0.03837949]]
# sum of pred 1.0000000000000002
# loss tensor(0.0515, dtype=torch.float64)
# 27
# x - C - mixture - Norm tensor([[11.2948, 11.7225, 11.5163]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.3000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.29478806 11.72253434 11.51632846]]
# Cal C - shape (3, 1)
# C original [[11.294787 11.722534 11.516328]]
# Cal B by Cal C
#  [[0.12834846]
#  [0.56019729]
#  [0.04804764]
#  [0.19293276]]
# pred [[0.12834908 0.56019592 0.04804824 0.19293294]]
# sum of pred 0.9295261782522272
# pred [[0.13808011 0.60266826 0.05169111 0.20756052]]
# sum of pred 0.9999999999999999
# loss tensor(0.1242, dtype=torch.float64)
# 28
# x - C - mixture - Norm tensor([[14.4111, 15.3251, 15.6190]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.3000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.41113228 15.32514893 15.61895681]]
# Cal C - shape (3, 1)
# C original [[14.411132 15.325149 15.618957]]
# Cal B by Cal C
#  [[0.03388452]
#  [0.08949191]
#  [0.23348354]
#  [0.62453466]]
# pred [[0.03388451 0.08949173 0.2334836  0.62453473]]
# sum of pred 0.981394566987616
# pred [[0.0345269  0.09118833 0.23791001 0.63637476]]
# sum of pred 1.0
# loss tensor(0.0355, dtype=torch.float64)
# 29
# x - C - mixture - Norm tensor([[12.6298, 13.3236, 12.8570]])
# y - B - ratio tensor([[0.6000, 0.0000, 0.0000, 0.4000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.6297621  13.32364737 12.85697841]]
# Cal C - shape (3, 1)
# C original [[12.629762 13.323647 12.856978]]
# Cal B by Cal C
#  [[0.43747986]
#  [0.05039988]
#  [0.3190326 ]
#  [0.28232467]]
# pred [[0.43747906 0.05040107 0.319032   0.28232464]]
# sum of pred 1.0892367707997443
# pred [[0.40163817 0.04627191 0.292895   0.25919492]]
# sum of pred 1.0
# loss tensor(0.1696, dtype=torch.float64)
# 30
# x - C - mixture - Norm tensor([[12.1966, 12.8928, 12.8801]])
# y - B - ratio tensor([[0.0000, 0.2000, 0.5000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.19656118 12.8927596  12.88010483]]
# Cal C - shape (3, 1)
# C original [[12.196561 12.892759 12.880105]]
# Cal B by Cal C
#  [[0.15095513]
#  [0.15318661]
#  [0.20366996]
#  [0.4093015 ]]
# pred [[0.15095486 0.15318663 0.20366988 0.40930165]]
# sum of pred 0.9171130224168504
# pred [[0.16459788 0.16703136 0.22207718 0.44629358]]
# sum of pred 1.0
# loss tensor(0.1554, dtype=torch.float64)
# 31
# x - C - mixture - Norm tensor([[14.5806, 15.4349, 15.6401]])
# y - B - ratio tensor([[0.1000, 0.2000, 0.1000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.58056675 15.43485486 15.64009166]]
# Cal C - shape (3, 1)
# C original [[14.580566  15.4348545 15.640091 ]]
# Cal B by Cal C
#  [[0.04955862]
#  [0.21564261]
#  [0.19901814]
#  [0.56347713]]
# pred [[0.04955887 0.21564245 0.19901825 0.56347703]]
# sum of pred 1.027696593969945
# pred [[0.04822325 0.20983085 0.19365468 0.54829123]]
# sum of pred 1.0
# loss tensor(0.0517, dtype=torch.float64)
# 32
# x - C - mixture - Norm tensor([[10.1396, 10.4673,  9.6924]])
# y - B - ratio tensor([[0.5000, 0.4000, 0.1000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.13963423 10.46725973  9.6923781 ]]
# Cal C - shape (3, 1)
# C original [[10.139634 10.467259  9.692378]]
# Cal B by Cal C
#  [[ 0.46718075]
#  [ 0.41017773]
#  [ 0.1644253 ]
#  [-0.0237633 ]]
# pred [[ 0.46718043  0.41017835  0.16442501 -0.02376337]]
# sum of pred 1.0180204146337841
# pred [[ 0.45891066  0.40291761  0.16151445 -0.02334272]]
# sum of pred 0.9999999999999999
# loss tensor(0.0322, dtype=torch.float64)
# 33
# x - C - mixture - Norm tensor([[11.3980, 12.0111, 11.8034]])
# y - B - ratio tensor([[0.1000, 0.2000, 0.5000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.39796242 12.01112222 11.8034392 ]]
# Cal C - shape (3, 1)
# C original [[11.397963 12.011122 11.803439]]
# Cal B by Cal C
#  [[0.24591427]
#  [0.15474985]
#  [0.21356534]
#  [0.30565157]]
# pred [[0.2459136  0.15475143 0.21356465 0.30565131]]
# sum of pred 0.9198809864624848
# pred [[0.26733198 0.16822984 0.23216552 0.33227266]]
# sum of pred 1.0
# loss tensor(0.1498, dtype=torch.float64)
# 34
# x - C - mixture - Norm tensor([[10.9500, 11.4517, 11.2391]])
# y - B - ratio tensor([[0.0000, 0.4000, 0.5000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.9500234  11.45171367 11.23905339]]
# Cal C - shape (3, 1)
# C original [[10.950024 11.451714 11.239054]]
# Cal B by Cal C
#  [[0.1887407 ]
#  [0.34146875]
#  [0.1294956 ]
#  [0.23666074]]
# pred [[0.18874018 0.34146976 0.12949514 0.23666064]]
# sum of pred 0.8963657122440791
# pred [[0.21056158 0.38094915 0.14446686 0.26402242]]
# sum of pred 1.0
# loss tensor(0.1873, dtype=torch.float64)
# 35
# x - C - mixture - Norm tensor([[10.7600, 11.1621, 10.3954]])
# y - B - ratio tensor([[0.6000, 0.3000, 0.0000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.75995571 11.16207876 10.39540156]]
# Cal C - shape (3, 1)
# C original [[10.759955 11.162078 10.395401]]
# Cal B by Cal C
#  [[0.49415821]
#  [0.33282311]
#  [0.20777106]
#  [0.02336354]]
# pred [[0.49415767 0.33282443 0.20777048 0.02336328]]
# sum of pred 1.0581158636984245
# pred [[0.4670166  0.31454441 0.19635891 0.02208008]]
# sum of pred 1.0
# loss tensor(0.1055, dtype=torch.float64)
# 36
# x - C - mixture - Norm tensor([[13.7879, 14.6046, 14.7984]])
# y - B - ratio tensor([[0.0000, 0.2000, 0.3000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.78786306 14.60462562 14.79843073]]
# Cal C - shape (3, 1)
# C original [[13.787863 14.604626 14.79843 ]]
# Cal B by Cal C
#  [[0.05277731]
#  [0.18363299]
#  [0.19639636]
#  [0.53821426]]
# pred [[0.05277781 0.18363197 0.19639682 0.53821438]]
# sum of pred 0.9710209700590676
# pred [[0.0543529  0.18911226 0.20225806 0.55427679]]
# sum of pred 1.0
# loss tensor(0.0543, dtype=torch.float64)
# 37
# x - C - mixture - Norm tensor([[ 9.8037, 10.2736,  9.7676]])
# y - B - ratio tensor([[0.2000, 0.2000, 0.6000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.803713   10.27355213  9.76761091]]
# Cal C - shape (3, 1)
# C original [[ 9.803713 10.273552  9.767611]]
# Cal B by Cal C
#  [[0.38996233]
#  [0.1410899 ]
#  [0.22709753]
#  [0.13754527]]
# pred [[0.38996243 0.14108989 0.22709756 0.1375452 ]]
# sum of pred 0.8956950840869813
# pred [[0.43537409 0.15752    0.25354338 0.15356253]]
# sum of pred 1.0000000000000002
# loss tensor(0.1945, dtype=torch.float64)
# 38
# x - C - mixture - Norm tensor([[15.8242, 16.8502, 17.1636]])
# y - B - ratio tensor([[0.2000, 0.0000, 0.0000, 0.8000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[15.8241565  16.8501962  17.16364021]]
# Cal C - shape (3, 1)
# C original [[15.824156 16.850197 17.16364 ]]
# Cal B by Cal C
#  [[0.05764328]
#  [0.0441469 ]
#  [0.27945108]
#  [0.69692434]]
# pred [[0.05764533 0.04414312 0.27945283 0.69692467]]
# sum of pred 1.0781659494094291
# pred [[0.0534661  0.04094279 0.25919278 0.64639833]]
# sum of pred 1.0
# loss tensor(0.1501, dtype=torch.float64)
# 39
# x - C - mixture - Norm tensor([[11.3832, 11.8826, 11.2159]])
# y - B - ratio tensor([[0.6000, 0.2000, 0.0000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.38322445 11.88260157 11.21592712]]
# Cal C - shape (3, 1)
# C original [[11.3832245 11.882601  11.215927 ]]
# Cal B by Cal C
#  [[0.47526543]
#  [0.23868203]
#  [0.24485824]
#  [0.10968392]]
# pred [[0.47526438 0.23868419 0.24485726 0.10968363]]
# sum of pred 1.0684894606269726
# pred [[0.44480025 0.22338469 0.22916207 0.10265298]]
# sum of pred 1.0
# loss tensor(0.1263, dtype=torch.float64)
# 40
# x - C - mixture - Norm tensor([[10.7659, 11.2135, 10.6304]])
# y - B - ratio tensor([[0.4000, 0.3000, 0.2000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.76585084 11.21348696 10.63040635]]
# Cal C - shape (3, 1)
# C original [[10.765851 11.213487 10.630406]]
# Cal B by Cal C
#  [[0.40241775]
#  [0.29925024]
#  [0.1952539 ]
#  [0.1017506 ]]
# pred [[0.40241722 0.29925145 0.19525337 0.10175041]]
# sum of pred 0.9986724472032136
# pred [[0.40295216 0.29964925 0.19551292 0.10188566]]
# sum of pred 1.0
# loss tensor(0.0024, dtype=torch.float64)
# 41
# x - C - mixture - Norm tensor([[12.5384, 13.1379, 13.0399]])
# y - B - ratio tensor([[0.1000, 0.4000, 0.2000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.53837797 13.13787585 13.0398772 ]]
# Cal C - shape (3, 1)
# C original [[12.538378 13.137876 13.039877]]
# Cal B by Cal C
#  [[0.13643311]
#  [0.38870157]
#  [0.12848058]
#  [0.32637999]]
# pred [[0.13643303 0.38870176 0.12848049 0.32637994]]
# sum of pred 0.9799952242454144
# pred [[0.13921806 0.39663638 0.13110318 0.33304238]]
# sum of pred 1.0
# loss tensor(0.0361, dtype=torch.float64)
# 42
# x - C - mixture - Norm tensor([[11.7368, 12.2305, 11.8457]])
# y - B - ratio tensor([[0.3000, 0.4000, 0.1000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.73683164 12.23053437 11.84570919]]
# Cal C - shape (3, 1)
# C original [[11.736832 12.230535 11.845709]]
# Cal B by Cal C
#  [[0.27726248]
#  [0.40705125]
#  [0.14463454]
#  [0.18353653]]
# pred [[0.27726293 0.40705071 0.14463483 0.18353648]]
# sum of pred 1.0124849457807898
# pred [[0.273844   0.40203137 0.14285134 0.18127329]]
# sum of pred 0.9999999999999999
# loss tensor(0.0224, dtype=torch.float64)
# 43
# x - C - mixture - Norm tensor([[10.9382, 11.3489, 10.7690]])
# y - B - ratio tensor([[0.4000, 0.4000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.93823293 11.34889705 10.76904364]]
# Cal C - shape (3, 1)
# C original [[10.938232 11.348897 10.769044]]
# Cal B by Cal C
#  [[0.37222162]
#  [0.40861449]
#  [0.15452992]
#  [0.07988661]]
# pred [[0.37222168 0.40861356 0.15453023 0.07988698]]
# sum of pred 1.0152524505881504
# pred [[0.36662968 0.40247483 0.15220867 0.07868681]]
# sum of pred 1.0
# loss tensor(0.0273, dtype=torch.float64)
# 44
# x - C - mixture - Norm tensor([[10.5935, 11.0781, 10.4918]])
# y - B - ratio tensor([[0.4000, 0.2000, 0.3000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.59346865 11.07807678 10.49176896]]
# Cal C - shape (3, 1)
# C original [[10.593469 11.078076 10.491769]]
# Cal B by Cal C
#  [[0.43261387]
#  [0.18988597]
#  [0.23597788]
#  [0.1236146 ]]
# pred [[0.4326134  0.18988704 0.23597741 0.12361442]]
# sum of pred 0.9820922723569772
# pred [[0.44050179 0.19334949 0.24028028 0.12586843]]
# sum of pred 1.0
# loss tensor(0.0332, dtype=torch.float64)
# 45
# x - C - mixture - Norm tensor([[11.1887, 11.4082, 11.1117]])
# y - B - ratio tensor([[0., 1., 0., 0.]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.18866535 11.40824155 11.11171455]]
# Cal C - shape (3, 1)
# C original [[11.188665 11.408241 11.111714]]
# Cal B by Cal C
#  [[ 0.05665286]
#  [ 0.98243112]
#  [-0.11121149]
#  [ 0.04102041]]
# pred [[ 0.05665259  0.98243189 -0.11121181  0.04102024]]
# sum of pred 0.968892912731764
# pred [[ 0.05847147  1.01397366 -0.11478235  0.04233723]]
# sum of pred 0.9999999999999999
# loss tensor(0.0574, dtype=torch.float64)
# 46
# x - C - mixture - Norm tensor([[11.2889, 11.6711, 11.2813]])
# y - B - ratio tensor([[0.2000, 0.6000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.28889272 11.67112592 11.28132348]]
# Cal C - shape (3, 1)
# C original [[11.288893 11.671125 11.281323]]
# Cal B by Cal C
#  [[0.22008891]
#  [0.59377016]
#  [0.06056479]
#  [0.1145457 ]]
# pred [[0.22008826 0.59377155 0.06056417 0.1145455 ]]
# sum of pred 0.988969478431763
# pred [[0.22254303 0.60039421 0.06123967 0.11582309]]
# sum of pred 1.0
# loss tensor(0.0194, dtype=torch.float64)
# 47
# x - C - mixture - Norm tensor([[12.3689, 13.0282, 13.0187]])
# y - B - ratio tensor([[0.0000, 0.3000, 0.4000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.36894351 13.02816994 13.01874236]]
# Cal C - shape (3, 1)
# C original [[12.368943 13.02817  13.018742]]
# Cal B by Cal C
#  [[0.12075901]
#  [0.26255088]
#  [0.16294598]
#  [0.38743751]]
# pred [[0.1207593  0.26255068 0.16294612 0.38743738]]
# sum of pred 0.9336934850400602
# pred [[0.12933506 0.2811958  0.17451778 0.41495136]]
# sum of pred 1.0000000000000002
# loss tensor(0.1221, dtype=torch.float64)
# 48
# x - C - mixture - Norm tensor([[12.0904, 12.5785, 12.4755]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.2000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.09043899 12.57846734 12.47549141]]
# Cal C - shape (3, 1)
# C original [[12.090439 12.578467 12.475492]]
# Cal B by Cal C
#  [[0.07925954]
#  [0.57542048]
#  [0.04441083]
#  [0.25738915]]
# pred [[0.07925961 0.57542009 0.04441098 0.25738928]]
# sum of pred 0.9564799500270103
# pred [[0.08286594 0.60160183 0.04643169 0.26910055]]
# sum of pred 0.9999999999999998
# loss tensor(0.0768, dtype=torch.float64)
# 49
# x - C - mixture - Norm tensor([[13.7820, 14.5532, 14.5634]])
# y - B - ratio tensor([[0.2000, 0.2000, 0.1000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.78196772 14.5532172  14.56342575]]
# Cal C - shape (3, 1)
# C original [[13.781968 14.553217 14.563426]]
# Cal B by Cal C
#  [[0.14451777]
#  [0.21720586]
#  [0.20891351]
#  [0.4598272 ]]
# pred [[0.14451699 0.2172076  0.20891275 0.45982694]]
# sum of pred 1.0304642702386044
# pred [[0.14024454 0.21078615 0.20273653 0.44623278]]
# sum of pred 1.0
# loss tensor(0.0568, dtype=torch.float64)
# 50
# x - C - mixture - Norm tensor([[11.3891, 11.9340, 11.4509]])
# y - B - ratio tensor([[0.4000, 0.2000, 0.2000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.38911958 11.93400977 11.45093191]]
# Cal C - shape (3, 1)
# C original [[11.389119 11.93401  11.450932]]
# Cal B by Cal C
#  [[0.38352496]
#  [0.20510916]
#  [0.23234108]
#  [0.18807098]]
# pred [[0.3835252  0.20510856 0.23234133 0.18807107]]
# sum of pred 1.0090461604474366
# pred [[0.38008687 0.20326975 0.23025837 0.186385  ]]
# sum of pred 1.0
# loss tensor(0.0168, dtype=torch.float64)
# 51
# x - C - mixture - Norm tensor([[10.4211, 10.9427, 10.3531]])
# y - B - ratio tensor([[0.4000, 0.1000, 0.4000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.42108641 10.94266653 10.3531315 ]]
# Cal C - shape (3, 1)
# C original [[10.421086 10.942666 10.353131]]
# Cal B by Cal C
#  [[0.46281   ]
#  [0.0805217 ]
#  [0.27670186]
#  [0.14547858]]
# pred [[0.46280959 0.08052264 0.27670145 0.14547843]]
# sum of pred 0.9655120975107417
# pred [[0.47934105 0.08339889 0.28658517 0.15067489]]
# sum of pred 0.9999999999999999
# loss tensor(0.0650, dtype=torch.float64)
# 52
# x - C - mixture - Norm tensor([[11.1195, 11.5614, 11.2602]])
# y - B - ratio tensor([[0.1000, 0.5000, 0.3000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.119458   11.56141974 11.26018838]]
# Cal C - shape (3, 1)
# C original [[11.119458  11.5614195 11.260188 ]]
# Cal B by Cal C
#  [[0.20441481]
#  [0.46761944]
#  [0.0950302 ]
#  [0.17560322]]
# pred [[0.20441453 0.46762048 0.09502979 0.17560294]]
# sum of pred 0.9426677392264073
# pred [[0.21684685 0.49606076 0.10080942 0.18628296]]
# sum of pred 1.0
# loss tensor(0.1016, dtype=torch.float64)
# 53
# x - C - mixture - Norm tensor([[13.6817, 14.2903, 14.3938]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.0000, 0.4000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.68174098 14.29033348 14.39381746]]
# Cal C - shape (3, 1)
# C original [[13.681741 14.290333 14.393817]]
# Cal B by Cal C
#  [[-0.01891828]
#  [ 0.60586686]
#  [ 0.03713723]
#  [ 0.38630192]]
# pred [[-0.01891868  0.60586794  0.03713677  0.38630168]]
# sum of pred 1.0103877045386056
# pred [[-0.01872418  0.59963906  0.03675497  0.38233015]]
# sum of pred 0.9999999999999999
# loss tensor(0.0184, dtype=torch.float64)
# 54
# x - C - mixture - Norm tensor([[ 9.7860, 10.1193,  9.0626]])
# y - B - ratio tensor([[0.8000, 0.2000, 0.0000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.78602704 10.11932694  9.06259604]]
# Cal C - shape (3, 1)
# C original [[ 9.786027 10.119327  9.062596]]
# Cal B by Cal C
#  [[ 0.6651837 ]
#  [ 0.24180852]
#  [ 0.264649  ]
#  [-0.09761592]]
# pred [[ 0.66518312  0.24180933  0.26464858 -0.0976159 ]]
# sum of pred 1.0740251226105892
# pred [[ 0.61933665  0.22514308  0.24640819 -0.09088791]]
# sum of pred 0.9999999999999998
# loss tensor(0.1358, dtype=torch.float64)
# 55
# x - C - mixture - Norm tensor([[16.6257, 17.7575, 18.3578]])
# y - B - ratio tensor([[0.0000, 0.0000, 0.1000, 0.9000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[16.62570212 17.75753692 18.35780743]]
# Cal C - shape (3, 1)
# C original [[16.625702 17.757538 18.357807]]
# Cal B by Cal C
#  [[-0.08318608]
#  [ 0.02579722]
#  [ 0.26329711]
#  [ 0.83976776]]
# pred [[-0.08318457  0.02579417  0.2632985   0.83976812]]
# sum of pred 1.0456762278740568
# pred [[-0.07955098  0.02466746  0.25179734  0.80308618]]
# sum of pred 1.0
# loss tensor(0.0882, dtype=torch.float64)
# 56
# x - C - mixture - Norm tensor([[13.3370, 14.0195, 14.1165]])
# y - B - ratio tensor([[0.0000, 0.4000, 0.2000, 0.4000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.33697647 14.01951296 14.11654254]]
# Cal C - shape (3, 1)
# C original [[13.336976 14.019513 14.116542]]
# Cal B by Cal C
#  [[0.04147397]
#  [0.38713832]
#  [0.1185852 ]
#  [0.4300299 ]]
# pred [[0.04147492 0.38713661 0.118586   0.43003003]]
# sum of pred 0.9772275479767547
# pred [[0.04244141 0.3961581  0.12134942 0.44005107]]
# sum of pred 1.0
# loss tensor(0.0412, dtype=torch.float64)
# 57
# x - C - mixture - Norm tensor([[11.9122, 12.3916, 12.1018]])
# y - B - ratio tensor([[0.2000, 0.5000, 0.1000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.91216129 12.39164856 12.10184888]]
# Cal C - shape (3, 1)
# C original [[11.912161 12.391648 12.101849]]
# Cal B by Cal C
#  [[0.20119612]
#  [0.49962907]
#  [0.09765198]
#  [0.20086607]]
# pred [[0.20119623 0.49962866 0.09765213 0.20086616]]
# sum of pred 0.9993431916759862
# pred [[0.20132847 0.49995704 0.09771631 0.20099818]]
# sum of pred 1.0
# loss tensor(0.0012, dtype=torch.float64)
# diff_list [[ 1.05546764e-02 -3.10296318e-03 -1.79930615e-02  1.05413110e-02]
#  [ 3.06783891e-02  5.93748435e-04 -5.85394003e-02  2.72672255e-02]
#  [ 2.68808710e-02  4.92086321e-04 -4.86213966e-02  2.12484095e-02]
#  [ 8.42695085e-02 -1.93782598e-02 -1.32377580e-01  6.74863088e-02]
#  [ 3.85587568e-02  7.09900413e-03 -7.56944400e-02  3.00367014e-02]
#  [ 2.48851962e-01 -3.61796356e-02 -4.06521990e-01  1.93849626e-01]
#  [ 5.46328914e-03 -1.52532804e-03 -8.85423215e-03  4.91625615e-03]
#  [-2.11217950e-02  5.10959753e-03  3.71065129e-02 -2.10943453e-02]
#  [-3.70429174e-02  1.31965015e-03  7.27139131e-02 -3.69906458e-02]
#  [ 2.73552315e-01 -2.47514347e-02 -4.46870776e-01  1.98069866e-01]
#  [-2.76793529e-02  6.36638782e-03  4.62182667e-02 -2.49053091e-02]
#  [ 1.45094470e-01 -3.33658418e-02 -2.20748175e-01  1.09019539e-01]
#  [-2.41839550e-01  5.01926592e-02  3.17727880e-01 -1.26080967e-01]
#  [-1.66478096e-01  3.58715594e-02  2.20709533e-01 -9.01030112e-02]
#  [-1.58824236e-01  4.22885924e-02  2.67681592e-01 -1.51145948e-01]
#  [ 4.58341732e-02 -1.06914526e-02 -6.01054972e-02  2.49627468e-02]
#  [ 1.53335345e-01 -1.31509826e-02 -2.53411457e-01  1.13227080e-01]
#  [-1.39808206e-01  3.06339071e-02  2.35632970e-01 -1.26458708e-01]
#  [-1.28323587e-01  2.95092199e-02  2.26976325e-01 -1.28161950e-01]
#  [ 7.05894299e-02  9.11840819e-03 -1.34695612e-01  5.49877590e-02]
#  [-6.42635762e-02  1.63408771e-02  9.76471709e-02 -4.97244866e-02]
#  [ 6.43678550e-02 -1.89212669e-02 -1.06379097e-01  6.09325018e-02]
#  [ 1.81520061e-01 -5.33622477e-02 -2.81093689e-01  1.52935839e-01]
#  [ 3.72902749e-01 -1.15644763e-01 -5.47739111e-01  2.90481147e-01]
#  [-1.51748842e-01  3.17525435e-02  2.44245114e-01 -1.24248824e-01]
#  [-6.29990859e-02  5.40310597e-03  1.17232628e-01 -5.96366559e-02]
#  [ 6.46475390e-02 -7.70627889e-03 -9.53207837e-02  3.83794938e-02]
#  [ 1.38080114e-01  2.66823132e-03 -2.48308905e-01  1.07560522e-01]
#  [ 3.45269010e-02 -8.81167395e-03 -6.20899979e-02  3.63747336e-02]
#  [-1.98361858e-01  4.62719121e-02  2.92894998e-01 -1.40805081e-01]
#  [ 1.64597878e-01 -3.29686446e-02 -2.77922817e-01  1.46293569e-01]
#  [-5.17767519e-02  9.83084465e-03  9.36546749e-02 -5.17087975e-02]
#  [-4.10893350e-02  2.91760515e-03  6.15144468e-02 -2.33427244e-02]
#  [ 1.67331975e-01 -3.17701678e-02 -2.67834476e-01  1.32272661e-01]
#  [ 2.10561576e-01 -1.90508543e-02 -3.55533145e-01  1.64022415e-01]
#  [-1.32983427e-01  1.45443968e-02  1.96358914e-01 -7.79199209e-02]
#  [ 5.43528994e-02 -1.08877471e-02 -9.77419541e-02  5.42767868e-02]
#  [ 2.35374087e-01 -4.24799998e-02 -3.46456648e-01  1.53562531e-01]
#  [-1.46533904e-01  4.09427897e-02  2.59192785e-01 -1.53601685e-01]
#  [-1.55199775e-01  2.33846915e-02  2.29162074e-01 -9.73470206e-02]
#  [ 2.95215885e-03 -3.50763539e-04 -4.48708105e-03  1.88566339e-03]
#  [ 3.92180580e-02 -3.36362590e-03 -6.88968209e-02  3.30423664e-02]
#  [-2.61560119e-02  2.03135944e-03  4.28513392e-02 -1.87267090e-02]
#  [-3.33703260e-02  2.47482724e-03  5.22086734e-02 -2.13131895e-02]
#  [ 4.05017850e-02 -6.65051080e-03 -5.97197299e-02  2.58684333e-02]
#  [ 5.84714682e-02  1.39736563e-02 -1.14782354e-01  4.23372298e-02]
#  [ 2.25430245e-02  3.94187720e-04 -3.87603269e-02  1.58230848e-02]
#  [ 1.29335062e-01 -1.88042148e-02 -2.25482225e-01  1.14951348e-01]
#  [ 8.28659383e-02  1.60180697e-03 -1.53568317e-01  6.91005420e-02]
#  [-5.97554644e-02  1.07861472e-02  1.02736526e-01 -5.37672161e-02]
#  [-1.99131357e-02  3.26974772e-03  3.02583717e-02 -1.36149986e-02]
#  [ 7.93410467e-02 -1.66011127e-02 -1.13414836e-01  5.06748875e-02]
#  [ 1.16846852e-01 -3.93923927e-03 -1.99190588e-01  8.62829599e-02]
#  [-1.87241833e-02 -3.60961752e-04  3.67549692e-02 -1.76698539e-02]
#  [-1.80663366e-01  2.51430787e-02  2.46408186e-01 -9.08879129e-02]
#  [-7.95509782e-02  2.46674583e-02  1.51797341e-01 -9.69137987e-02]
#  [ 4.24414118e-02 -3.84190544e-03 -7.86505832e-02  4.00510620e-02]
#  [ 1.32846560e-03 -4.29604978e-05 -2.28369089e-03  9.98178336e-04]]
# 0
# x - C - mixture - Norm tensor([[11.4214, 11.9583, 11.5827]])
# y - B - ratio tensor([[0.3000, 0.2000, 0.3000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.39206736 11.95971409 11.5684345 ]]
# Cal C - shape (3, 1)
# C original [[11.421425 11.958341 11.582748]]
# Cal B by Cal C
#  [[0.33765474]
#  [0.18832272]
#  [0.22608251]
#  [0.22726451]]
# pred [[0.30684334 0.26789311 0.19247781 0.21279096]]
# sum of pred 0.9800052202164807
# pred [[0.31310378 0.27335886 0.19640488 0.21713247]]
# sum of pred 1.0
# loss tensor(0.0518, dtype=torch.float64)
# 1
# x - C - mixture - Norm tensor([[11.1863, 11.8557, 11.5108]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.5000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.22263261 11.85000787 11.54729937]]
# Cal C - shape (3, 1)
# C original [[11.186277  11.855735  11.5108385]]
# Cal B by Cal C
#  [[0.32198063]
#  [0.06217202]
#  [0.2605479 ]
#  [0.28832203]]
# pred [[ 0.3777058  -0.05397715  0.31248832  0.30243136]]
# sum of pred 0.9386483315935055
# pred [[ 0.4023933  -0.05750519  0.3329131   0.32219879]]
# sum of pred 1.0
# loss tensor(0.1623, dtype=torch.float64)
# 2
# x - C - mixture - Norm tensor([[13.7856, 14.6007, 14.8183]])
# y - B - ratio tensor([[0.0000, 0.2000, 0.3000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.78786306 14.60462562 14.79843073]]
# Cal C - shape (3, 1)
# C original [[13.785593 14.600731 14.818326]]
# Cal B by Cal C
#  [[0.05277731]
#  [0.18363299]
#  [0.19639636]
#  [0.53821426]]
# pred [[0.03613087 0.19587286 0.188036   0.54378081]]
# sum of pred 0.9638205434985909
# pred [[0.03748713 0.20322545 0.19509441 0.56419301]]
# sum of pred 1.0
# loss tensor(0.0525, dtype=torch.float64)
# 3
# x - C - mixture - Norm tensor([[ 9.9904, 10.4954, 10.1030]])
# y - B - ratio tensor([[0.0000, 0.3000, 0.7000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.98199017 10.46037036 10.14125293]]
# Cal C - shape (3, 1)
# C original [[ 9.990409  10.4954195 10.102961 ]]
# Cal B by Cal C
#  [[0.26802574]
#  [0.21688131]
#  [0.17385638]
#  [0.19406834]]
# pred [[0.3332062  0.1304231  0.21925876 0.19011013]]
# sum of pred 0.8729981835799908
# pred [[0.38168029 0.14939676 0.25115603 0.21776692]]
# sum of pred 1.0
# loss tensor(0.2997, dtype=torch.float64)
# 4
# x - C - mixture - Norm tensor([[11.1231, 11.5806, 11.1572]])
# y - B - ratio tensor([[0.2000, 0.5000, 0.2000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.11651029 11.53571549 11.14268585]]
# Cal C - shape (3, 1)
# C original [[11.123108 11.580573 11.157213]]
# Cal B by Cal C
#  [[0.25028504]
#  [0.48440588]
#  [0.10128878]
#  [0.13640969]]
# pred [[0.2946751  0.38743889 0.14475291 0.15140915]]
# sum of pred 0.9782760512438773
# pred [[0.30121877 0.39604249 0.14796734 0.1547714 ]]
# sum of pred 0.9999999999999999
# loss tensor(0.0780, dtype=torch.float64)
# 5
# x - C - mixture - Norm tensor([[14.3982, 15.3207, 15.6616]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.3000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.41113228 15.32514893 15.61895681]]
# Cal C - shape (3, 1)
# C original [[14.39822  15.320741 15.66165 ]]
# Cal B by Cal C
#  [[0.03388452]
#  [0.08949191]
#  [0.23348354]
#  [0.62453466]]
# pred [[0.00867041 0.08600722 0.22789799 0.64272198]]
# sum of pred 0.9652975909872745
# pred [[0.00898211 0.08909917 0.23609091 0.66582781]]
# sum of pred 1.0
# loss tensor(0.0374, dtype=torch.float64)
# 6
# x - C - mixture - Norm tensor([[16.8095, 17.9102, 18.5311]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.0000, 0.9000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[16.7980843  17.8929471  18.49644481]]
# Cal C - shape (3, 1)
# C original [[16.809528 17.910234 18.531061]]
# Cal B by Cal C
#  [[-0.11338221]
#  [ 0.13516148]
#  [ 0.22257312]
#  [ 0.81790377]]
# pred [[-0.12131876  0.13003825  0.22241298  0.82623643]]
# sum of pred 1.0573688953620994
# pred [[-0.11473646  0.12298286  0.21034568  0.78140792]]
# sum of pred 1.0
# loss tensor(0.1167, dtype=torch.float64)
# 7
# x - C - mixture - Norm tensor([[10.6832, 10.8995, 10.3186]])
# y - B - ratio tensor([[0.3000, 0.7000, 0.0000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.66267591 10.9248985  10.34329503]]
# Cal C - shape (3, 1)
# C original [[10.683174  10.899495  10.3185835]]
# Cal B by Cal C
#  [[ 0.28485193]
#  [ 0.70469763]
#  [ 0.0297362 ]
#  [-0.01096821]]
# pred [[ 0.2543815   0.81173633 -0.01297245 -0.03883009]]
# sum of pred 1.0143152915665758
# pred [[ 0.25079135  0.80028008 -0.01278937 -0.03828207]]
# sum of pred 1.0
# loss tensor(0.0501, dtype=torch.float64)
# 8
# x - C - mixture - Norm tensor([[12.6526, 13.4481, 13.4634]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.5000, 0.4000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.64450007 13.45216801 13.44449049]]
# Cal C - shape (3, 1)
# C original [[12.652592 13.448076 13.463384]]
# Cal B by Cal C
#  [[ 0.2081287 ]
#  [-0.03353229]
#  [ 0.2877397 ]
#  [ 0.47829233]]
# pred [[0.18496667 0.0037719  0.26963651 0.47717838]]
# sum of pred 0.93555346576578
# pred [[0.19770829 0.00403173 0.28821069 0.51004929]]
# sum of pred 0.9999999999999999
# loss tensor(0.1059, dtype=torch.float64)
# 9
# x - C - mixture - Norm tensor([[10.1137, 10.5097,  9.7008]])
# y - B - ratio tensor([[0.5000, 0.4000, 0.1000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.13963423 10.46725973  9.6923781 ]]
# Cal C - shape (3, 1)
# C original [[10.1137085 10.509666   9.700796 ]]
# Cal B by Cal C
#  [[ 0.46718075]
#  [ 0.41017773]
#  [ 0.1644253 ]
#  [-0.0237633 ]]
# pred [[0.53412049 0.23917357 0.23748698 0.00862592]]
# sum of pred 1.0194069712481344
# pred [[0.52395217 0.2346203  0.23296582 0.00846171]]
# sum of pred 0.9999999999999999
# loss tensor(0.0827, dtype=torch.float64)
# 10
# x - C - mixture - Norm tensor([[ 9.7868, 10.1810,  9.3035]])
# y - B - ratio tensor([[0.6000, 0.2000, 0.2000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.79192245 10.17073543  9.29760107]]
# Cal C - shape (3, 1)
# C original [[ 9.78685  10.181019  9.303529]]
# Cal B by Cal C
#  [[ 0.57344325]
#  [ 0.20823565]
#  [ 0.25213185]
#  [-0.01922886]]
# pred [[ 0.58630683  0.17114019  0.26756309 -0.01104641]]
# sum of pred 1.0139636970734756
# pred [[ 0.57823256  0.16878335  0.26387837 -0.01089428]]
# sum of pred 0.9999999999999999
# loss tensor(0.0319, dtype=torch.float64)
# 11
# x - C - mixture - Norm tensor([[12.7490, 13.3015, 13.2925]])
# y - B - ratio tensor([[0.0000, 0.5000, 0.2000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.71370769 13.29899012 13.29601696]]
# Cal C - shape (3, 1)
# C original [[12.749012 13.301475 13.292504]]
# Cal B by Cal C
#  [[0.06036675]
#  [0.48127939]
#  [0.08149802]
#  [0.34370953]]
# pred [[0.04233715 0.55832206 0.05212683 0.32197811]]
# sum of pred 0.9747641483749776
# pred [[0.04343323 0.57277656 0.05347635 0.33031386]]
# sum of pred 1.0
# loss tensor(0.0733, dtype=torch.float64)
# 12
# x - C - mixture - Norm tensor([[10.2747, 10.7745, 10.1827]])
# y - B - ratio tensor([[0.4000, 0.0000, 0.5000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.24870417 10.80725628 10.21449405]]
# Cal C - shape (3, 1)
# C original [[10.274662 10.774462 10.182728]]
# Cal B by Cal C
#  [[ 0.49300612]
#  [-0.02884256]
#  [ 0.31742584]
#  [ 0.16734257]]
# pred [[0.45391808 0.10817676 0.26272846 0.13172001]]
# sum of pred 0.9565433082541703
# pred [[0.47454002 0.11309133 0.27466447 0.13770418]]
# sum of pred 0.9999999999999999
# loss tensor(0.1127, dtype=torch.float64)
# 13
# x - C - mixture - Norm tensor([[10.7850, 11.1745, 10.4654]])
# y - B - ratio tensor([[0.5000, 0.3000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.76290313 11.18778272 10.51290383]]
# Cal C - shape (3, 1)
# C original [[10.785008 11.17452  10.465398]]
# Cal B by Cal C
#  [[0.44828797]
#  [0.31603667]
#  [0.20151247]
#  [0.06255707]]
# pred [[0.44754194 0.38642028 0.17855735 0.0314982 ]]
# sum of pred 1.0440177675751254
# pred [[0.42867272 0.37012807 0.17102903 0.03017018]]
# sum of pred 0.9999999999999999
# loss tensor(0.0706, dtype=torch.float64)
# 14
# x - C - mixture - Norm tensor([[15.9985, 16.9945, 17.5056]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.1000, 0.8000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[16.00243395 17.03701472 17.5372825 ]]
# Cal C - shape (3, 1)
# C original [[15.998514 16.994476 17.505608]]
# Cal B by Cal C
#  [[-0.0642933 ]
#  [ 0.1199383 ]
#  [ 0.22620993]
#  [ 0.75344741]]
# pred [[-0.09616752  0.21082616  0.18802128  0.73286124]]
# sum of pred 1.0355411539443435
# pred [[-0.09286693  0.20359032  0.18156814  0.70770847]]
# sum of pred 1.0
# loss tensor(0.0926, dtype=torch.float64)
# 15
# x - C - mixture - Norm tensor([[13.9991, 14.6687, 14.6603]])
# y - B - ratio tensor([[0.2000, 0.3000, 0.0000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.95434998 14.68862746 14.70206321]]
# Cal C - shape (3, 1)
# C original [[13.999092 14.668661 14.660283]]
# Cal B by Cal C
#  [[0.11432164]
#  [0.32657013]
#  [0.16818953]
#  [0.43796321]]
# pred [[0.08597091 0.47120446 0.11408825 0.39238906]]
# sum of pred 1.0636526783773483
# pred [[0.08082611 0.44300594 0.10726081 0.36890713]]
# sum of pred 1.0
# loss tensor(0.1251, dtype=torch.float64)
# 16
# x - C - mixture - Norm tensor([[10.9269, 11.3969, 11.1614]])
# y - B - ratio tensor([[0.1000, 0.4000, 0.4000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.94707584 11.42600957 11.12155101]]
# Cal C - shape (3, 1)
# C original [[10.926916 11.396892 11.161441]]
# Cal B by Cal C
#  [[0.23461093]
#  [0.35825519]
#  [0.13575418]
#  [0.19746721]]
# pred [[0.18393499 0.40143715 0.10812187 0.21103523]]
# sum of pred 0.9045292446437907
# pred [[0.20334886 0.44380782 0.11953386 0.23330946]]
# sum of pred 1.0
# loss tensor(0.1402, dtype=torch.float64)
# 17
# x - C - mixture - Norm tensor([[11.5796, 12.1182, 11.7771]])
# y - B - ratio tensor([[0.2000, 0.3000, 0.3000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.56739718 12.12082845 11.82457435]]
# Cal C - shape (3, 1)
# C original [[11.579614 12.118178 11.777122]]
# Cal B by Cal C
#  [[0.26158838]
#  [0.28090055]
#  [0.17909994]
#  [0.24459406]]
# pred [[0.28121755 0.29954234 0.17824667 0.22315528]]
# sum of pred 0.9821618346578275
# pred [[0.28632507 0.30498267 0.18148401 0.22720826]]
# sum of pred 1.0
# loss tensor(0.0593, dtype=torch.float64)
# 18
# x - C - mixture - Norm tensor([[14.1187, 14.8776, 15.0032]])
# y - B - ratio tensor([[0.1000, 0.4000, 0.0000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.1296797  14.84974172 14.95820296]]
# Cal C - shape (3, 1)
# C original [[14.118741 14.877603 15.003237]]
# Cal B by Cal C
#  [[0.03825529]
#  [0.41914795]
#  [0.12120697]
#  [0.45529275]]
# pred [[0.05216313 0.33621141 0.15188347 0.48373121]]
# sum of pred 1.023989224544663
# pred [[0.05094109 0.32833491 0.14832526 0.47239874]]
# sum of pred 1.0
# loss tensor(0.0742, dtype=torch.float64)
# 19
# x - C - mixture - Norm tensor([[12.0292, 12.6205, 12.2817]])
# y - B - ratio tensor([[0.4000, 0.1000, 0.2000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.01238854 12.65453281 12.2714577 ]]
# Cal C - shape (3, 1)
# C original [[12.02915  12.620499 12.281689]]
# Cal B by Cal C
#  [[0.36463217]
#  [0.11096808]
#  [0.26942826]
#  [0.27439136]]
# pred [[0.30242894 0.24482566 0.20964605 0.25555319]]
# sum of pred 1.0124538372956806
# pred [[0.29870887 0.24181414 0.20706727 0.25240972]]
# sum of pred 1.0
# loss tensor(0.0744, dtype=torch.float64)
# 20
# x - C - mixture - Norm tensor([[14.4373, 15.2668, 15.2886]])
# y - B - ratio tensor([[0.3000, 0.1000, 0.0000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.40228937 15.24803641 15.26644943]]
# Cal C - shape (3, 1)
# C original [[14.437279 15.266821 15.288553]]
# Cal B by Cal C
#  [[0.17149521]
#  [0.13985122]
#  [0.25225928]
#  [0.50695406]]
# pred [[0.15802036 0.18273227 0.23529487 0.49793716]]
# sum of pred 1.0739846551502508
# ...
# sum of pred 1.0
# loss tensor(0.8910, dtype=torch.float64)
# 37
# x - C - mixture - Norm tensor([[14.9526, 13.1794, 14.4264]])
# y - B - ratio tensor([[0.0000, 0.0000, 0.5000, 0.5000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[13.44309857 14.33380512 14.52115583]]
# Cal C - shape (3, 1)
# C original [[14.952641 13.17937  14.426411]]
# Cal B by Cal C
#  [[ 0.11316956]
#  [-0.03509554]
#  [ 0.27784432]
#  [ 0.58194224]]
# pred [[-2.33430483  6.60335802 -2.51057667 -0.75441231]]
# sum of pred 1.004064215955697
# pred [[-2.32485611  6.57662918 -2.50041445 -0.75135863]]
# sum of pred 1.0
# loss tensor(3.2883, dtype=torch.float64)
# 38
# x - C - mixture - Norm tensor([[10.3844, 11.8868, 10.3328]])
# y - B - ratio tensor([[0.2000, 0.8000, 0.0000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.8380059  11.08601303 10.59943505]]
# Cal C - shape (3, 1)
# C original [[10.384431 11.886822 10.332849]]
# Cal B by Cal C
#  [[ 0.20878557]
#  [ 0.79727548]
#  [-0.01724637]
#  [ 0.00636133]]
# pred [[ 1.72893876 -2.50432837  1.45294143  0.47869342]]
# sum of pred 1.1562452362799143
# pred [[ 1.49530455 -2.16591454  1.25660317  0.41400683]]
# sum of pred 1.0
# loss tensor(1.4830, dtype=torch.float64)
# 39
# x - C - mixture - Norm tensor([[ 9.9004, 12.8857, 10.7882]])
# y - B - ratio tensor([[0.0000, 0.4000, 0.4000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.74567447 12.30764682 12.19821649]]
# Cal C - shape (3, 1)
# C original [[ 9.900416 12.885739 10.788246]]
# Cal B by Cal C
#  [[0.13965179]
#  [0.35669194]
#  [0.1258588 ]
#  [0.30111713]]
# pred [[ 3.05192673 -6.13174365  2.97890779  1.23500726]]
# sum of pred 1.1340981282950664
# pred [[ 2.69106055 -5.40671349  2.62667552  1.08897742]]
# sum of pred 1.0
# loss tensor(2.9034, dtype=torch.float64)
# 40
# x - C - mixture - Norm tensor([[12.6439, 11.0935, 10.9118]])
# y - B - ratio tensor([[0.0000, 0.3000, 0.6000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.77764152 11.3163038  11.10041631]]
# Cal C - shape (3, 1)
# C original [[12.643873 11.093479 10.911775]]
# Cal B by Cal C
#  [[0.21893684]
#  [0.23210449]
#  [0.17021959]
#  [0.25852473]]
# pred [[-1.19292473  5.23725414 -1.80749632 -1.0097182 ]]
# sum of pred 1.2271148913076706
# pred [[-0.97213777  4.26794115 -1.47296421 -0.82283917]]
# sum of pred 0.9999999999999991
# loss tensor(1.9840, dtype=torch.float64)
# 41
# x - C - mixture - Norm tensor([[13.2041, 11.6602, 11.3901]])
# y - B - ratio tensor([[0.0000, 0.9000, 0.0000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.81193392 12.1287642  11.93223995]]
# Cal C - shape (3, 1)
# C original [[13.204064 11.660231 11.390102]]
# Cal B by Cal C
#  [[ 0.03776007]
#  [ 0.88829002]
#  [-0.0741243 ]
#  [ 0.12734079]]
# pred [[-1.14450803  5.26899139 -1.79556637 -1.03064946]]
# sum of pred 1.2982675418687692
# pred [[-0.88156562  4.05847888 -1.38304803 -0.79386523]]
# sum of pred 1.0000000000000009
# loss tensor(1.5792, dtype=torch.float64)
# 42
# x - C - mixture - Norm tensor([[12.9963, 11.0994, 12.6410]])
# y - B - ratio tensor([[0.1000, 0.2000, 0.4000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.19361362 12.8670555  12.76260244]]
# Cal C - shape (3, 1)
# C original [[12.996321 11.099373 12.640963]]
# Cal B by Cal C
#  [[0.19682536]
#  [0.16997304]
#  [0.20992854]
#  [0.37010797]]
# pred [[-2.55877625  6.71522031 -2.63978228 -0.74677963]]
# sum of pred 0.7698821563192821
# pred [[-3.3235947   8.72240025 -3.42881343 -0.96999212]]
# sum of pred 1.0000000000000009
# loss tensor(4.2612, dtype=torch.float64)
# 43
# x - C - mixture - Norm tensor([[ 9.3641, 12.1649, 11.0146]])
# y - B - ratio tensor([[0.7000, 0.3000, 0.0000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.96135672 10.28044115  9.31873576]]
# Cal C - shape (3, 1)
# C original [[ 9.364103 12.164884 11.014628]]
# Cal B by Cal C
#  [[ 0.58911732]
#  [ 0.33438635]
#  [ 0.21766643]
#  [-0.08028637]]
# pred [[ 2.32323237 -5.43655868  2.5527983   1.38390806]]
# sum of pred 0.8233800564985372
# pred [[ 2.8215796  -6.60273301  3.10038879  1.68076461]]
# sum of pred 1.0000000000000002
# loss tensor(3.4514, dtype=torch.float64)
# 44
# x - C - mixture - Norm tensor([[10.0516, 13.0057, 11.3759]])
# y - B - ratio tensor([[0.7000, 0.0000, 0.1000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.03551212 11.58607668 10.82114959]]
# Cal C - shape (3, 1)
# C original [[10.051598 13.005667 11.375889]]
# Cal B by Cal C
#  [[0.58152788]
#  [0.03673994]
#  [0.33256477]
#  [0.11421837]]
# pred [[ 2.72020259 -5.86483493  2.80820531  1.3446681 ]]
# sum of pred 1.008241067988829
# pred [[ 2.69796845 -5.81689749  2.78525186  1.33367717]]
# sum of pred 1.0
# loss tensor(2.9084, dtype=torch.float64)
# 45
# x - C - mixture - Norm tensor([[13.3253, 17.6128, 14.6044]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.2000, 0.7000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[15.03145275 16.01996688 16.32197921]]
# Cal C - shape (3, 1)
# C original [[13.325332 17.612844 14.604409]]
# Cal B by Cal C
#  [[0.06086197]
#  [0.01213728]
#  [0.27682929]
#  [0.67166147]]
# pred [[ 4.40288568 -8.93190234  4.30890971  1.77571724]]
# sum of pred 1.555610288889456
# pred [[ 2.83032692 -5.74173519  2.76991592  1.14149235]]
# sum of pred 0.9999999999999998
# loss tensor(2.8709, dtype=torch.float64)
# 46
# x - C - mixture - Norm tensor([[12.3629, 16.6282, 13.6676]])
# y - B - ratio tensor([[0.3000, 0.0000, 0.1000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.2299072  15.11262623 15.12781205]]
# Cal C - shape (3, 1)
# C original [[12.362939 16.628218 13.667564]]
# Cal B by Cal C
#  [[0.20169134]
#  [0.03048696]
#  [0.29298326]
#  [0.52881805]]
# pred [[ 4.38119883 -9.00051154  4.30890985  1.77628405]]
# sum of pred 1.4658811961615765
# pred [[ 2.98878166 -6.14000068  2.93946731  1.21175171]]
# sum of pred 1.0
# loss tensor(3.0700, dtype=torch.float64)
# 47
# x - C - mixture - Norm tensor([[10.9526,  9.1677,  8.8136]])
# y - B - ratio tensor([[0.7000, 0.2000, 0.1000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[ 9.78897447 10.14503089  9.1800983 ]]
# Cal C - shape (3, 1)
# C original [[10.9525795  9.167721   8.813566 ]]
# Cal B by Cal C
#  [[ 0.61931345]
#  [ 0.22502208]
#  [ 0.25839041]
#  [-0.05842238]]
# pred [[-1.18784165  5.46303783 -1.91028705 -1.19871468]]
# sum of pred 1.166194456514239
# pred [[-1.01856225  4.68449992 -1.6380519  -1.02788576]]
# sum of pred 0.9999999999999998
# loss tensor(2.2422, dtype=torch.float64)
# 48
# x - C - mixture - Norm tensor([[12.7217, 12.6142, 11.4371]])
# y - B - ratio tensor([[0.0000, 0.7000, 0.1000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.26282074 12.71387709 12.61412838]]
# Cal C - shape (3, 1)
# C original [[12.7217455 12.614241  11.437084 ]]
# Cal B by Cal C
#  [[0.04906341]
#  [0.68478471]
#  [0.00368686]
#  [0.23552516]]
# pred [[ 0.38775064  1.61149352 -0.20569212 -0.40297914]]
# sum of pred 1.3905728918960754
# pred [[ 0.27884237  1.15887022 -0.14791898 -0.28979361]]
# sum of pred 1.0000000000000002
# loss tensor(0.3689, dtype=torch.float64)
# 49
# x - C - mixture - Norm tensor([[10.6110, 10.9006, 13.3058]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.6000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.02417922 12.75734965 12.74146766]]
# Cal C - shape (3, 1)
# C original [[10.610963 10.900571 13.305757]]
# Cal B by Cal C
#  [[0.18115126]
#  [0.04382234]
#  [0.24439395]
#  [0.43116549]]
# pred [[-1.66220466  1.75101235 -0.81761179  0.82895688]]
# sum of pred 0.10015278289835516
# pred [[-16.59668966  17.48341182  -8.16364524   8.27692307]]
# sum of pred 1.0000000000000018
# loss tensor(12.6802, dtype=torch.float64)
# 50
# x - C - mixture - Norm tensor([[ 9.2582, 10.6024, 10.3257]])
# y - B - ratio tensor([[0.3000, 0.2000, 0.4000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.59641629 11.10378095 10.6092714 ]]
# Cal C - shape (3, 1)
# C original [[ 9.258246 10.602403 10.325659]]
# Cal B by Cal C
#  [[0.38674365]
#  [0.17309953]
#  [0.2297193 ]
#  [0.16280812]]
# pred [[ 0.81469177 -1.82924309  0.97517548  0.73520325]]
# sum of pred 0.695827409798069
# pred [[ 1.17082449 -2.62887472  1.40146172  1.05658851]]
# sum of pred 1.0
# loss tensor(1.4144, dtype=torch.float64)
# 51
# x - C - mixture - Norm tensor([[ 9.9217, 11.9129, 13.0913]])
# y - B - ratio tensor([[0.1000, 0.5000, 0.3000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.119458   11.56141974 11.26018838]]
# Cal C - shape (3, 1)
# C original [[ 9.921707 11.912948 13.091273]]
# Cal B by Cal C
#  [[0.20441481]
#  [0.46761944]
#  [0.0950302 ]
#  [0.17560322]]
# pred [[ 0.25626532 -2.6556935   1.1146883   1.53071144]]
# sum of pred 0.24597155929855585
# pred [[  1.04184939 -10.79675028   4.53177719   6.2231237 ]]
# sum of pred 1.0000000000000018
# loss tensor(5.6484, dtype=torch.float64)
# 52
# x - C - mixture - Norm tensor([[13.2692, 13.5122, 12.7943]])
# y - B - ratio tensor([[0.2000, 0.4000, 0.2000, 0.2000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[11.7397792  12.25623847 11.96321158]]
# Cal C - shape (3, 1)
# C original [[13.269184 13.512219 12.794295]]
# Cal B by Cal C
#  [[0.23139225]
#  [0.39026481]
#  [0.13837596]
#  [0.22273006]]
# pred [[ 0.29709936  1.06761448 -0.04051228 -0.0628996 ]]
# sum of pred 1.2613019581359879
# pred [[ 0.23554975  0.84643845 -0.03211942 -0.04986879]]
# sum of pred 1.0000000000000002
# loss tensor(0.2410, dtype=torch.float64)
# 53
# x - C - mixture - Norm tensor([[15.5252, 15.7573, 14.8845]])
# y - B - ratio tensor([[0.0000, 0.0000, 0.3000, 0.7000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[15.03440045 16.04567113 16.43948174]]
# Cal C - shape (3, 1)
# C original [[15.52521  15.757302 14.884524]]
# Cal B by Cal C
#  [[ 0.01499174]
#  [-0.00464916]
#  [ 0.27057071]
#  [ 0.710855  ]]
# pred [[ 0.3356044   1.3551464  -0.08537148 -0.11454864]]
# sum of pred 1.4908306869576722
# pred [[ 0.22511235  0.90898746 -0.05726437 -0.07683544]]
# sum of pred 0.9999999999999999
# loss tensor(0.5670, dtype=torch.float64)
# 54
# x - C - mixture - Norm tensor([[13.3674, 15.0957, 15.3196]])
# y - B - ratio tensor([[0.2000, 0.2000, 0.0000, 0.6000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[14.57761911 15.40915068 15.52258921]]
# Cal C - shape (3, 1)
# C original [[13.367394 15.095677 15.319578]]
# Cal B by Cal C
#  [[0.09542885]
#  [0.23242905]
#  [0.20527672]
#  [0.5242836 ]]
# pred [[ 0.6293462  -1.92748946  1.03215916  1.10359343]]
# sum of pred 0.8376093385574328
# pred [[ 0.75136006 -2.30117952  1.23226797  1.31755149]]
# sum of pred 0.9999999999999998
# loss tensor(1.2506, dtype=torch.float64)
# 55
# x - C - mixture - Norm tensor([[11.4344, 10.5215,  7.4598]])
# y - B - ratio tensor([[0.9000, 0.1000, 0.0000, 0.0000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[9.61069688 9.95821222 8.80645588]]
# Cal C - shape (3, 1)
# C original [[11.434379  10.521523   7.4598145]]
# Cal B by Cal C
#  [[ 0.74125002]
#  [ 0.14923069]
#  [ 0.31163155]
#  [-0.11494545]]
# pred [[ 1.14274002  2.54698565 -0.34137406 -1.41287019]]
# sum of pred 1.9354814117840071
# pred [[ 0.59041643  1.31594426 -0.17637682 -0.72998386]]
# sum of pred 1.0000000000000002
# loss tensor(0.6080, dtype=torch.float64)
# 56
# x - C - mixture - Norm tensor([[14.0843, 12.2761, 13.5013]])
# y - B - ratio tensor([[0.2000, 0.3000, 0.2000, 0.3000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[12.36304824 12.97676159 12.78373745]]
# Cal C - shape (3, 1)
# C original [[14.084331 12.276081 13.501304]]
# Cal B by Cal C
#  [[0.21249946]
#  [0.29612375]
#  [0.17546314]
#  [0.30905045]]
# pred [[-2.320723    6.55096148 -2.50515252 -0.78090571]]
# sum of pred 0.9441802532077993
# pred [[-2.45792368  6.93825301 -2.65325663 -0.8270727 ]]
# sum of pred 1.0000000000000009
# loss tensor(3.3191, dtype=torch.float64)
# 57
# x - C - mixture - Norm tensor([[11.2634,  9.7583,  7.8624]])
# y - B - ratio tensor([[0.8000, 0.0000, 0.1000, 0.1000]])
# A - shape (3, 4)
# B - shape (4, 1)
# C - shape (3, 1)
# Cal C
#  [[10.23691369 10.70443966  9.7444843 ]]
# Cal C - shape (3, 1)
# C original [[11.263444   9.758306   7.8623805]]
# Cal B by Cal C
#  [[0.67648704]
#  [0.03830318]
#  [0.34246016]
#  [0.01056845]]
# pred [[-1.00753137e-03  4.29837238e+00 -1.21553984e+00 -1.45311357e+00]]
# sum of pred 1.6287114368379634
# pred [[-6.18606435e-04  2.63912458e+00 -7.46319954e-01 -8.92186018e-01]]
# sum of pred 1.0
# loss tensor(1.3196, dtype=torch.float64)
# diff_list [[ 1.05360605e+01  3.68911210e+00 -3.76113161e-01 -1.38490595e+01]
#  [ 2.09801553e+00 -7.24440116e+00  3.01412051e+00  2.13226510e+00]
#  [ 1.18507929e+00 -1.65110773e+00  6.88126723e-01 -2.22098319e-01]
#  [ 2.17644288e+00 -4.98928840e+00  2.31825347e+00  4.94592041e-01]
#  [-2.64622784e+00  6.78032644e+00 -3.42727289e+00 -7.06825701e-01]
#  [-1.98157197e+00  2.20514008e+00 -1.05212188e+00  8.28553776e-01]
#  [-2.16394227e-01  4.63992831e-01 -1.08211302e-01 -1.39387332e-01]
#  [ 5.27619834e-01  4.98262199e-01 -4.50988111e-02 -9.80783214e-01]
#  [-3.52898358e-01  1.27047621e+00 -5.94132037e-01 -3.23445844e-01]
#  [-2.65596163e-01  1.32564280e+00 -3.06498907e-01 -7.53547710e-01]
#  [-3.79146202e+00  5.68869899e+00 -2.74020252e+00  8.42965522e-01]
#  [-1.42792869e+00  2.45489807e+00 -8.50203128e-01 -1.76766260e-01]
#  [-1.96590001e+00  6.29750334e+00 -3.02283195e+00 -1.30877140e+00]
#  [-2.64342851e+00  1.76755068e+00 -8.64429814e-01  1.74030764e+00]
#  [-9.22346250e-01 -6.43653741e-01  1.71108975e-01  1.39489101e+00]
#  [ 5.93986239e-01 -4.86550682e-01  3.94572682e-01 -5.02008269e-01]
#  [ 9.27455371e-02  5.09581347e-01 -3.86546083e-01 -2.15780793e-01]
#  [-1.13743092e+00  3.48483982e+00 -1.34239429e+00 -1.00501465e+00]
#  [-9.40639196e-01  1.21578607e+00 -6.20680257e-01  3.45533369e-01]
#  [ 2.67634049e+00 -5.81110528e+00  2.44490328e+00  6.89861488e-01]
#  [ 1.00171150e+00 -1.62577031e+00  5.38893031e-01  8.51657852e-02]
#  [-1.70140883e-01  1.79793161e+00 -9.16952819e-01 -7.10837922e-01]
#  [ 4.94259840e-01 -3.54789927e+00  1.64730321e+00  1.40633618e+00]
#  [-5.83139265e-02  1.07521456e+00 -7.78562621e-01 -2.38338040e-01]
#  [-2.73826800e+00  6.44823207e+00 -2.86783629e+00 -8.42127811e-01]
#  [-2.41357893e+00  6.26896861e+00 -2.82452614e+00 -1.03086357e+00]
#  [-2.28405801e+00  5.46395815e+00 -2.29891393e+00 -8.80986236e-01]
#  [ 1.44179171e+00 -2.60307757e+00  1.01146342e+00  1.49822421e-01]
#  [-1.75146194e+00 -1.68651254e+00  7.20741954e-01  2.71723253e+00]
#  [ 2.67862279e-02  1.86729779e+00 -8.46453825e-01 -1.04763023e+00]
#  [-4.36153493e-01  9.60288016e-03  3.23897062e-04  4.26226679e-01]
#  [ 2.32367295e+00 -1.15645225e+01  4.53575611e+00  4.70509346e+00]
#  [ 1.54351687e+00 -2.92663383e+00  1.20038358e+00  1.82733375e-01]
#  [ 2.13363098e+00 -3.65544234e+00  1.30299016e+00  2.18821202e-01]
#  [ 1.13519365e+00 -2.24772515e+00  3.12623460e-01  7.99908069e-01]
#  [-2.95851391e+01  3.76667192e+01 -1.74757151e+01  9.39413494e+00]
#  [ 7.59471460e-02 -1.78202496e+00  7.91207892e-01  9.14869908e-01]
#  [-2.32485611e+00  6.57662918e+00 -3.00041445e+00 -1.25135863e+00]
#  [ 1.29530454e+00 -2.96591455e+00  1.25660317e+00  4.14006829e-01]
#  [ 2.69106055e+00 -5.80671349e+00  2.22667551e+00  8.88977419e-01]
#  [-9.72137767e-01  3.96794114e+00 -2.07296423e+00 -9.22839172e-01]
#  [-8.81565617e-01  3.15847890e+00 -1.38304803e+00 -8.93865231e-01]
#  [-3.42359470e+00  8.52240025e+00 -3.82881344e+00 -1.26999213e+00]
#  [ 2.12157962e+00 -6.90273302e+00  3.10038879e+00  1.68076461e+00]
#  [ 1.99796846e+00 -5.81689749e+00  2.68525186e+00  1.13367717e+00]
#  [ 2.73032692e+00 -5.74173519e+00  2.56991592e+00  4.41492359e-01]
#  [ 2.68878165e+00 -6.14000068e+00  2.83946731e+00  6.11751686e-01]
#  [-1.71856224e+00  4.48449991e+00 -1.73805190e+00 -1.02788576e+00]
#  [ 2.78842369e-01  4.58870234e-01 -2.47918979e-01 -4.89793617e-01]
#  [-1.65966897e+01  1.73834118e+01 -8.76364527e+00  7.97692306e+00]
#  [ 8.70824477e-01 -2.82887472e+00  1.00146172e+00  9.56588508e-01]
#  [ 9.41849385e-01 -1.12967503e+01  4.23177718e+00  6.12312370e+00]
#  [ 3.55497491e-02  4.46438448e-01 -2.32119419e-01 -2.49868794e-01]
#  [ 2.25112353e-01  9.08987461e-01 -3.57264383e-01 -7.76835431e-01]
#  [ 5.51360056e-01 -2.50117952e+00  1.23226797e+00  7.17551465e-01]
#  [-3.09583548e-01  1.21594425e+00 -1.76376823e-01 -7.29983861e-01]
#  [-2.65792368e+00  6.63825300e+00 -2.85325664e+00 -1.12707271e+00]
#  [-8.00618618e-01  2.63912458e+00 -8.46319955e-01 -9.92186019e-01]]
