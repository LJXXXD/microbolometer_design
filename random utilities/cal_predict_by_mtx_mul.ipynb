# %%
import fcntl
import os
import platform
from tkinter import Tk
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import scipy.stats as stats
from sklearn.cluster import KMeans

import sys
sys.path.insert(0, os.path.abspath('.'))
from tools import Sim_Parameters, Train_Parameters, create_dataset, RMSELoss, train_val_test, test_epoch, simulator, ballsINTObins, load_data, NoisyDataset

# %%
def solve_for_B(A, C):
    # Calculate the Moore-Penrose pseudoinverse of matrix A
    A_pseudo_inv = np.linalg.pinv(A)
    
    # Calculate matrix B
    B = np.dot(A_pseudo_inv, C)
    
    return B

# # Example matrices A and C (you can replace these with your own matrices)
# A = np.array([[1, 2], [3, 4], [5, 6]])
# C = np.array([[7, 8], [9, 10], [11, 12]])

# # Solve for matrix B
# B = solve_for_B(A, C)

# print("Matrix B:")
# print(B)



substance_ind_list = [0, 1, 2, 3]
substance_ind_list.sort()

basis_func_ind_list = [0, 1, 4, 6]
# basis_func_ind_list = [0, 1, 2, 3, 4]
basis_func_ind_list.sort()

temp_K_list = np.asarray([293.15])
temp_K_list.sort()


air_trans, basis_funcs, spectra, substances_emit = load_data(air_trans_file='./data/Test 3 - 4 White Powers/Air transmittance.xlsx',
                                                             basis_func_file='./data/Test 3 - 4 White Powers/Basis functions_4-20um.xlsx',
                                                             spectra_file='./data/Test 3 - 4 White Powers/white_powders_spectra.xlsx', 
                                                             substances_emit_file='./data/Test 3 - 4 White Powers/white_powders.xlsx',)


substance_names = np.array(pd.read_excel('./data/Test 3 - 4 White Powers/white_powders_names.xlsx', header=None))

b_f_comb = [0, 1, 4, 6]
comb = b_f_comb
temp_K = 293.15

sim_params = Sim_Parameters(air_trans=air_trans,
                            air_RI=1,
                            atm_dist_ratio=0.11,
                            basis_funcs=basis_funcs,
                            basis_func_comb=comb,
                            substance_ind_list=substance_ind_list,
                            spectra=spectra,
                            substances_emit=substances_emit,
                            temp_K=temp_K,
                            percentage_step=0.05)

dataset = create_dataset(sim_params)

# %%
sensor_output_list = []

for idx in substance_ind_list:
    sub_signal = substances_emit[:, idx]
    sub_signal = np.expand_dims(sub_signal, 1)
    
    out = simulator(sim_params, sub_signal)  # Apply simulator() function to the column
    sensor_output_list.append(out)

sensor_output_list = np.asarray(sensor_output_list).transpose()
print(sensor_output_list.shape)
# Out:
# (4, 4)

# %%
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

torch.manual_seed(28)
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# test_noise_perc_list = [0, 0.01, 0.03, 0.05, 0.1, 0.2, 0.4, 1, 2]
test_noise_perc_list = [i * 0.2 for i in range(11)]
print(test_noise_perc_list)
# Out:
# [0.0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0, 1.2000000000000002, 1.4000000000000001, 1.6, 1.8, 2.0]

# %%
results = []

for test_noise_perc in test_noise_perc_list:
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
    if test_noise_perc != 0:
        test_dataset = NoisyDataset(test_dataset, test_noise_perc)


    dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

    loss_list = []
    targ_list = []
    pred_list = []

    

    for batch_idx, (x, y) in enumerate(dataloader):
        print(batch_idx)
        print('x - C - mixture - Norm', x)
        print('y - B - ratio', y)

        print('A - shape', sensor_output_list.shape)
        print('B - shape', y.numpy().transpose().shape)
        print('C - shape', x.numpy().transpose().shape)

        X = np.matmul(sensor_output_list, y.numpy().transpose())
        print('Cal C\n', X.transpose())
        print('Cal C - shape', X.shape)
        print('C original', x.numpy())

        Cal_B_by_Cal_C = solve_for_B(sensor_output_list, X)
        print('Cal B by Cal C\n', Cal_B_by_Cal_C)

        prediction = solve_for_B(sensor_output_list, x.numpy().transpose())
        print('pred', prediction.transpose())
        print('sum of pred', np.sum(prediction))
        normalized_prediction = prediction / np.sum(prediction)
        prediction = normalized_prediction
        print('pred', prediction.transpose())
        print('sum of pred', np.sum(prediction))

        criterion = nn.L1Loss()

        loss = criterion(torch.from_numpy(prediction.transpose()), y)
        print('loss', loss)
        loss_list.append(loss.numpy())
        targ_list.append(np.squeeze(y.numpy()))
        pred_list.append(np.squeeze(prediction))

    avg_loss = np.mean(loss_list)
    targ_list = np.asarray(targ_list)
    pred_list = np.asarray(pred_list)
    # print('avg loss', avg_loss)
    # print(pred_list.shape)
    # print(targ_list.shape)
    diff_list = pred_list - targ_list

    print('diff_list', diff_list)


    row = {
        'Temperature_K': temp_K,
        'Substance Number': len(substance_ind_list),
        'Substance Comb': tuple(substance_ind_list),
        'Basis Function Number': len(comb),
        'Comb of Basis Functions': comb,
        'Train Noise Max Percentage': 0,
        'Test Noise Max Percentage': test_noise_perc,
        'L1Loss': avg_loss
    }



    perc95_interval = []
    for i, sub_ind in enumerate(substance_ind_list):

        data = diff_list[:, i]
        # params = stats.norm.fit(data)
        # data_mean, data_std = params
        ae, loce, scalee = stats.skewnorm.fit(data)
        
        # Add mean and std to row
        # row[f'Substance {sub_ind} skewnorm a'] = ae
        # row[f'Substance {sub_ind} skewnorm loc'] = loce
        # row[f'Substance {sub_ind} skewnorm scale'] = scalee


        # Create a skewed normal distribution object
        dist = stats.skewnorm(ae, loce, scalee)


        for confidence_perc in (0.68, 0.95, 0.997):
            # Calculate the quantiles for a specific percentage
            lower_quantile = dist.ppf(0.5-confidence_perc/2)  # Lower quantile covering % of the data
            upper_quantile = dist.ppf(0.5+confidence_perc/2)  # Upper quantile covering % of the data

            # row[f'Substance {sub_ind} skewnorm {confidence_perc*100}% low'] = lower_quantile
            # row[f'Substance {sub_ind} skewnorm {confidence_perc*100}% high'] = upper_quantile
            # row[f'Substance {sub_ind} skewnorm {confidence_perc*100}% interval range'] = upper_quantile - lower_quantile

            if confidence_perc == 0.95:
                perc95_interval.append(upper_quantile - lower_quantile)


    # perc95_min = np.min(perc95_interval)
    # row[f'MIN skewnorm 95% interval range'] = perc95_min
    # perc95_max = np.max(perc95_interval)
    # row[f'MAX skewnorm 95% interval range'] = perc95_max
    perc95_avg = np.mean(perc95_interval)
    row[f'AVG skewnorm 95% interval range'] = perc95_avg


    # Append the row to the results list
    results.append(row)
# Create a pandas DataFrame from the results list
df = pd.DataFrame(results)



# df.to_csv('.csv', index=False)

output_file_name = 'loss_test_mtx_m.csv'
# Check if the file "loss.pkl" already exists
if os.path.isfile(output_file_name):

    # If the file exists, load the existing DataFrame from the file
    df_existing = pd.read_csv(output_file_name)

    # Open the file in binary mode
    with open(output_file_name, 'w') as f:
        while True:
            try:
                # Get a lock on the file
                fcntl.flock(f, fcntl.LOCK_EX | fcntl.LOCK_NB)
                break
            except IOError:
                # Lock is held by another process, wait and try again
                time.sleep(1)

        # Merge df to df_existing, and if there's duplicates, keep the new values from df
        df = pd.concat([df, df_existing]).drop_duplicates(
            subset=['Temperature_K', 'Substance Number', 'Substance Comb', 'Basis Function Number', 
                    'Comb of Basis Functions', 'Train Noise Max Percentage', 'Test Noise Max Percentage'], keep='first')
        df = df.sort_values(by=list(df.columns))
        print(df)

        # Save the DataFrame to a CSV file "loss.csv"
        df.to_csv(output_file_name, index=False)

        # Release the lock on the file
        fcntl.flock(f, fcntl.LOCK_UN)
else:
    # Save the DataFrame to a CSV file "loss.csv"
    df.to_csv(output_file_name, index=False)
# Out:
# 0
# x - C - mixture - Norm tensor([[10.9125, 11.5026,  8.4389,  8.1775]])
# y - B - ratio tensor([[0.1500, 0.1500, 0.5500, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.91247226 11.50259877  8.43893004  8.17751197]]
# Cal C - shape (4, 1)
# C original [[10.912472 11.502599  8.43893   8.177512]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.15000001]
#  [0.55000001]
#  [0.15000001]]
# pred [[0.1500012  0.14999869 0.54999766 0.15000146]]
# sum of pred 0.9999990030694903
# pred [[0.15000135 0.14999884 0.54999821 0.1500016 ]]
# sum of pred 1.0
# loss tensor(1.4771e-06, dtype=torch.float64)
# 1
# x - C - mixture - Norm tensor([[12.9347, 13.5530, 10.3539, 11.1120]])
# y - B - ratio tensor([[0.1500, 0.4000, 0.1000, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.93472936 13.55298999 10.35387576 11.11198089]]
# Cal C - shape (4, 1)
# C original [[12.93473  13.55299  10.353876 11.11198 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.40000001]
#  [0.1       ]
#  [0.34999999]]
# pred [[0.14999922 0.40000072 0.10000166 0.34999907]]
# sum of pred 1.000000674278958
# pred [[0.14999912 0.40000045 0.10000159 0.34999883]]
# sum of pred 1.0
# loss tensor(1.0218e-06, dtype=torch.float64)
# 2
# x - C - mixture - Norm tensor([[13.7002, 14.5241, 11.6332, 11.8849]])
# y - B - ratio tensor([[0.0500, 0.1500, 0.3000, 0.5000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.7001982  14.52406848 11.63319856 11.8848628 ]]
# Cal C - shape (4, 1)
# C original [[13.700198 14.524068 11.633199 11.884863]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.15000001]
#  [0.30000001]
#  [0.5       ]]
# pred [[0.04999879 0.15000148 0.30000206 0.4999986 ]]
# sum of pred 1.0000009243371721
# pred [[0.04999874 0.15000134 0.30000179 0.49999813]]
# sum of pred 1.0
# loss tensor(1.5575e-06, dtype=torch.float64)
# 3
# x - C - mixture - Norm tensor([[13.1086, 13.7013, 10.6021, 11.6002]])
# y - B - ratio tensor([[0.1000, 0.5000, 0.0500, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.10858523 13.70125213 10.60213544 11.60021178]]
# Cal C - shape (4, 1)
# C original [[13.108585 13.701252 10.602136 11.600212]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.5       ]
#  [0.05      ]
#  [0.34999999]]
# pred [[0.09999944 0.50000072 0.0500009  0.34999936]]
# sum of pred 1.0000004104510758
# pred [[0.0999994  0.50000051 0.05000088 0.34999922]]
# sum of pred 1.0
# loss tensor(6.9322e-07, dtype=torch.float64)
# 4
# x - C - mixture - Norm tensor([[13.0379, 13.8416, 10.4817, 10.3770]])
# y - B - ratio tensor([[0.2500, 0.0000, 0.3000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.0379039  13.84157805 10.48172005 10.37696451]]
# Cal C - shape (4, 1)
# C original [[13.037904  13.8415785 10.48172   10.376965 ]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.        ]
#  [0.30000001]
#  [0.44999999]]
# pred [[ 2.50001081e-01 -1.36172989e-06  2.99998076e-01  4.50001322e-01]]
# sum of pred 0.9999991179107468
# pred [[ 2.50001302e-01 -1.36173109e-06  2.99998340e-01  4.50001719e-01]]
# sum of pred 1.0
# loss tensor(1.5167e-06, dtype=torch.float64)
# 5
# x - C - mixture - Norm tensor([[ 9.9658, 10.3190,  6.1825,  6.3611]])
# y - B - ratio tensor([[0.5500, 0.3000, 0.1500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.96577846 10.3189977   6.18252438  6.36107337]]
# Cal C - shape (4, 1)
# C original [[ 9.965778 10.318997  6.182524  6.361073]]
# Cal B by Cal C
#  [[5.50000012e-01]
#  [3.00000012e-01]
#  [1.50000006e-01]
#  [3.55271368e-15]]
# pred [[ 5.49999607e-01  3.00000515e-01  1.50000809e-01 -5.46695272e-07]]
# sum of pred 1.0000003850677608
# pred [[ 5.49999395e-01  3.00000400e-01  1.50000752e-01 -5.46695062e-07]]
# sum of pred 1.0
# loss tensor(5.7429e-07, dtype=torch.float64)
# 6
# x - C - mixture - Norm tensor([[10.4122, 10.8656,  6.3696,  6.2693]])
# y - B - ratio tensor([[0.7000, 0.1000, 0.1000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.41224329 10.86555379  6.36959414  6.26932337]]
# Cal C - shape (4, 1)
# C original [[10.412243  10.865554   6.369594   6.2693233]]
# Cal B by Cal C
#  [[0.69999999]
#  [0.1       ]
#  [0.1       ]
#  [0.1       ]]
# pred [[0.70000082 0.09999883 0.09999844 0.10000113]]
# sum of pred 0.9999992150793986
# pred [[0.70000137 0.0999989  0.09999852 0.10000121]]
# sum of pred 0.9999999999999999
# loss tensor(1.2925e-06, dtype=torch.float64)
# 7
# x - C - mixture - Norm tensor([[13.8291, 14.6590, 10.8738, 11.0395]])
# y - B - ratio tensor([[0.4000, 0.0000, 0.0500, 0.5500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.8291338  14.65895524 10.87378056 11.03954669]]
# Cal C - shape (4, 1)
# C original [[13.829134 14.658955 10.87378  11.039546]]
# Cal B by Cal C
#  [[ 4.00000006e-01]
#  [-7.10542736e-15]
#  [ 5.00000007e-02]
#  [ 5.50000012e-01]]
# pred [[3.99998533e-01 1.96978550e-06 5.00028807e-02 5.49997991e-01]]
# sum of pred 1.0000013745837748
# pred [[3.99997984e-01 1.96978279e-06 5.00028119e-02 5.49997235e-01]]
# sum of pred 1.0
# loss tensor(2.3951e-06, dtype=torch.float64)
# 8
# x - C - mixture - Norm tensor([[11.0863, 11.6509,  8.6872,  8.6657]])
# y - B - ratio tensor([[0.1000, 0.2500, 0.5000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.08632803 11.6508608   8.68718963  8.66574279]]
# Cal C - shape (4, 1)
# C original [[11.086328 11.650861  8.687189  8.665743]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.25      ]
#  [0.5       ]
#  [0.15000001]]
# pred [[0.10000116 0.24999872 0.49999775 0.15000139]]
# sum of pred 0.9999990288400618
# pred [[0.10000126 0.24999897 0.49999824 0.15000154]]
# sum of pred 1.0
# loss tensor(1.3966e-06, dtype=torch.float64)
# 9
# x - C - mixture - Norm tensor([[15.6017, 16.5833, 13.5096, 14.0747]])
# y - B - ratio tensor([[0.1000, 0.1000, 0.0500, 0.7500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[15.60166062 16.5833438  13.50957152 14.07465792]]
# Cal C - shape (4, 1)
# C original [[15.601661 16.583344 13.509571 14.074657]]
# Cal B by Cal C
#  [[0.1 ]
#  [0.1 ]
#  [0.05]
#  [0.75]]
# pred [[0.09999943 0.10000093 0.0500012  0.74999906]]
# sum of pred 1.000000630461109
# pred [[0.09999936 0.10000087 0.05000117 0.74999859]]
# sum of pred 1.0
# loss tensor(1.0223e-06, dtype=torch.float64)
# 10
# x - C - mixture - Norm tensor([[14.5806, 15.4349, 12.3680, 12.9582]])
# y - B - ratio tensor([[0.1000, 0.2000, 0.1000, 0.6000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[14.58056675 15.43485486 12.36803587 12.95815816]]
# Cal C - shape (4, 1)
# C original [[14.580566  15.4348545 12.368035  12.958158 ]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.2       ]
#  [0.1       ]
#  [0.60000002]]
# pred [[0.10000012 0.19999993 0.09999992 0.60000004]]
# sum of pred 0.9999999970429769
# pred [[0.10000012 0.19999993 0.09999992 0.60000004]]
# sum of pred 1.0
# loss tensor(7.2799e-08, dtype=torch.float64)
# 11
# x - C - mixture - Norm tensor([[10.7548, 11.0440,  7.9556,  9.0579]])
# y - B - ratio tensor([[0.1000, 0.7500, 0.1500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.75476236 11.04401202  7.95563398  9.05790582]]
# Cal C - shape (4, 1)
# C original [[10.754763 11.044012  7.955634  9.057906]]
# Cal B by Cal C
#  [[1.00000001e-01]
#  [7.50000000e-01]
#  [1.50000006e-01]
#  [3.55271368e-15]]
# pred [[ 9.99995958e-02  7.50000628e-01  1.50000671e-01 -5.27857033e-07]]
# sum of pred 1.0000003665304007
# pred [[ 9.99995592e-02  7.50000353e-01  1.50000616e-01 -5.27856839e-07]]
# sum of pred 1.0
# loss tensor(4.8323e-07, dtype=torch.float64)
# 12
# x - C - mixture - Norm tensor([[ 9.8376, 10.2636,  5.4151,  5.0611]])
# y - B - ratio tensor([[0.8500, 0.0000, 0.1000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.83761448 10.26362115  5.4151282   5.06107353]]
# Cal C - shape (4, 1)
# C original [[ 9.837614  10.263621   5.415128   5.0610733]]
# Cal B by Cal C
#  [[ 8.50000024e-01]
#  [-3.55271368e-15]
#  [ 1.00000001e-01]
#  [ 5.00000007e-02]]
# pred [[ 8.50001002e-01 -1.48725535e-06  9.99982739e-02  5.00013404e-02]]
# sum of pred 0.9999991292282182
# pred [[ 8.50001742e-01 -1.48725664e-06  9.99983610e-02  5.00013840e-02]]
# sum of pred 1.0
# loss tensor(1.5574e-06, dtype=torch.float64)
# 13
# x - C - mixture - Norm tensor([[11.6175, 12.2523,  8.7797,  8.6515]])
# y - B - ratio tensor([[0.3000, 0.1000, 0.3500, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.61751044 12.2522702   8.77974243  8.65151067]]
# Cal C - shape (4, 1)
# C original [[11.617511 12.25227   8.779742  8.65151 ]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.1       ]
#  [0.34999999]
#  [0.25      ]]
# pred [[0.29999858 0.10000197 0.35000276 0.24999803]]
# sum of pred 1.0000013390411375
# pred [[0.29999818 0.10000184 0.35000229 0.24999769]]
# sum of pred 1.0
# loss tensor(2.0696e-06, dtype=torch.float64)
# 14
# x - C - mixture - Norm tensor([[12.0042, 12.5108,  9.7009, 10.5173]])
# y - B - ratio tensor([[0.0000, 0.5500, 0.2500, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.00424774 12.51076208  9.70088134 10.51725928]]
# Cal C - shape (4, 1)
# C original [[12.004248 12.510762  9.700881 10.517259]]
# Cal B by Cal C
#  [[3.55271368e-15]
#  [5.50000012e-01]
#  [2.50000000e-01]
#  [2.00000003e-01]]
# pred [[4.40519941e-07 5.49999456e-01 2.49999470e-01 2.00000405e-01]]
# sum of pred 0.999999771522738
# pred [[4.40520041e-07 5.49999582e-01 2.49999527e-01 2.00000451e-01]]
# sum of pred 1.0
# loss tensor(4.4801e-07, dtype=torch.float64)
# 15
# x - C - mixture - Norm tensor([[11.0385, 11.6118,  7.3880,  7.1101]])
# y - B - ratio tensor([[0.6000, 0.0000, 0.2000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.0384601  11.61178122  7.3879826   7.11006537]]
# Cal C - shape (4, 1)
# C original [[11.03846   11.611781   7.3879824  7.110065 ]]
# Cal B by Cal C
#  [[ 6.00000024e-01]
#  [-3.55271368e-15]
#  [ 2.00000003e-01]
#  [ 2.00000003e-01]]
# pred [[ 6.00000431e-01 -5.92325001e-07  1.99999340e-01  2.00000504e-01]]
# sum of pred 0.9999996829241518
# pred [[ 6.00000621e-01 -5.92325189e-07  1.99999403e-01  2.00000568e-01]]
# sum of pred 1.0
# loss tensor(5.8854e-07, dtype=torch.float64)
# 16
# x - C - mixture - Norm tensor([[12.1862, 12.8028,  9.1511,  9.4155]])
# y - B - ratio tensor([[0.3500, 0.2000, 0.1500, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.18624446 12.802795    9.15115017  9.41550019]]
# Cal C - shape (4, 1)
# C original [[12.186244 12.802794  9.15115   9.4155  ]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.2       ]
#  [0.15000001]
#  [0.30000001]]
# pred [[0.34999986 0.20000016 0.15000027 0.29999981]]
# sum of pred 1.0000001046563902
# pred [[0.34999983 0.20000014 0.15000025 0.29999978]]
# sum of pred 1.0
# loss tensor(1.9479e-07, dtype=torch.float64)
# 17
# x - C - mixture - Norm tensor([[13.1115, 13.7270, 10.8937, 11.8223]])
# y - B - ratio tensor([[0.0000, 0.5000, 0.1500, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.1115329  13.72695634 10.89366475 11.82234213]]
# Cal C - shape (4, 1)
# C original [[13.111533 13.726956 10.893664 11.822342]]
# Cal B by Cal C
#  [[0.        ]
#  [0.5       ]
#  [0.15000001]
#  [0.34999999]]
# pred [[-1.77983257e-07  5.00000514e-01  1.50000462e-01  3.49999528e-01]]
# sum of pred 1.0000003256422367
# pred [[-1.77983199e-07  5.00000351e-01  1.50000413e-01  3.49999414e-01]]
# sum of pred 1.0
# loss tensor(3.7912e-07, dtype=torch.float64)
# 18
# x - C - mixture - Norm tensor([[13.8321, 14.6847, 11.1653, 11.2617]])
# y - B - ratio tensor([[0.3000, 0.0000, 0.1500, 0.5500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.83208154 14.68465953 11.1653099  11.26167707]]
# Cal C - shape (4, 1)
# C original [[13.832081 14.684659 11.16531  11.261677]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.        ]
#  [0.15000001]
#  [0.55000001]]
# pred [[ 3.00000096e-01 -4.24685581e-07  1.49999750e-01  5.50000338e-01]]
# sum of pred 0.9999997597688015
# pred [[ 3.00000168e-01 -4.24685683e-07  1.49999786e-01  5.50000470e-01]]
# sum of pred 1.0
# loss tensor(3.1476e-07, dtype=torch.float64)
# 19
# x - C - mixture - Norm tensor([[12.9045, 13.6681, 10.8038, 10.8891]])
# y - B - ratio tensor([[0.0500, 0.1500, 0.4000, 0.4000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.90454726 13.66813548 10.80384451 10.88908554]]
# Cal C - shape (4, 1)
# C original [[12.904547 13.668136 10.803844 10.889086]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.15000001]
#  [0.40000001]
#  [0.40000001]]
# pred [[0.05000129 0.14999828 0.3999975  0.40000175]]
# sum of pred 0.9999988149536776
# pred [[0.05000135 0.14999846 0.39999797 0.40000223]]
# sum of pred 1.0
# loss tensor(1.7886e-06, dtype=torch.float64)
# 20
# x - C - mixture - Norm tensor([[10.9883, 11.4803,  7.4698,  7.5886]])
# y - B - ratio tensor([[0.5000, 0.2000, 0.1500, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.98834648 11.4803391   7.46982503  7.58863865]]
# Cal C - shape (4, 1)
# C original [[10.988346  11.480339   7.469825   7.5886383]]
# Cal B by Cal C
#  [[0.5       ]
#  [0.2       ]
#  [0.15000001]
#  [0.15000001]]
# pred [[0.50000061 0.19999915 0.14999895 0.15000077]]
# sum of pred 0.9999994875265728
# pred [[0.50000087 0.19999925 0.14999903 0.15000085]]
# sum of pred 1.0
# loss tensor(8.6068e-07, dtype=torch.float64)
# 21
# x - C - mixture - Norm tensor([[12.7623, 13.4176, 10.2514, 10.7348]])
# y - B - ratio tensor([[0.1500, 0.3000, 0.2000, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.76234727 13.4175799  10.25138071 10.73481514]]
# Cal C - shape (4, 1)
# C original [[12.762347 13.41758  10.251381 10.734815]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.30000001]
#  [0.2       ]
#  [0.34999999]]
# pred [[0.14999933 0.30000059 0.2000014  0.34999923]]
# sum of pred 1.0000005432777606
# pred [[0.14999925 0.30000042 0.20000129 0.34999904]]
# sum of pred 1.0
# loss tensor(8.5219e-07, dtype=torch.float64)
# 22
# x - C - mixture - Norm tensor([[ 9.5422, 10.0447,  6.6551,  5.9735]])
# y - B - ratio tensor([[0.3000, 0.0500, 0.6500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.54219171 10.04473228  6.65510947  5.97348433]]
# Cal C - shape (4, 1)
# C original [[ 9.5421915 10.044732   6.6551094  5.9734845]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.05      ]
#  [0.64999998]
#  [0.        ]]
# pred [[3.00000100e-01 4.99999185e-02 6.49999667e-01 1.61120386e-07]]
# sum of pred 0.9999998468413764
# pred [[3.00000146e-01 4.99999261e-02 6.49999767e-01 1.61120411e-07]]
# sum of pred 1.0
# loss tensor(1.4483e-07, dtype=torch.float64)
# 23
# x - C - mixture - Norm tensor([[10.3223, 10.6926,  7.5536,  8.0039]])
# y - B - ratio tensor([[0.1500, 0.5000, 0.3500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.32233304 10.69263443  7.55363149  8.00392607]]
# Cal C - shape (4, 1)
# C original [[10.322333  10.692635   7.5536313  8.003926 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.5       ]
#  [0.34999999]
#  [0.        ]]
# pred [[ 1.49999996e-01  5.00000299e-01  3.50000001e-01 -1.73904485e-07]]
# sum of pred 1.0000001228830477
# pred [[ 1.49999978e-01  5.00000238e-01  3.49999958e-01 -1.73904464e-07]]
# sum of pred 1.0
# loss tensor(1.1897e-07, dtype=torch.float64)
# 24
# x - C - mixture - Norm tensor([[11.4333, 12.0140,  7.5111,  7.3858]])
# y - B - ratio tensor([[0.7000, 0.0000, 0.0500, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.43333755 12.01404315  7.51113015  7.38582349]]
# Cal C - shape (4, 1)
# C original [[11.433337  12.014043   7.5111303  7.3858237]]
# Cal B by Cal C
#  [[ 6.99999988e-01]
#  [-7.10542736e-15]
#  [ 5.00000007e-02]
#  [ 2.50000000e-01]]
# pred [[ 6.99999921e-01 -7.82297711e-08  4.99999122e-02  2.50000115e-01]]
# sum of pred 0.9999998698725143
# pred [[ 7.00000012e-01 -7.82297813e-08  4.99999187e-02  2.50000148e-01]]
# sum of pred 1.0
# loss tensor(8.2944e-08, dtype=torch.float64)
# 25
# x - C - mixture - Norm tensor([[11.0473, 11.6889,  8.2626,  7.7765]])
# y - B - ratio tensor([[0.3000, 0.0000, 0.5000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.04730287 11.68889359  8.26257035  7.77645626]]
# Cal C - shape (4, 1)
# C original [[11.047302  11.688893   8.26257    7.7764564]]
# Cal B by Cal C
#  [[ 3.00000012e-01]
#  [-3.55271368e-15]
#  [ 5.00000000e-01]
#  [ 2.00000003e-01]]
# pred [[ 3.00000523e-01 -8.60842725e-07  4.99998867e-01  2.00000858e-01]]
# sum of pred 0.9999993883451062
# pred [[ 3.00000707e-01 -8.60843252e-07  4.99999173e-01  2.00000981e-01]]
# sum of pred 0.9999999999999999
# loss tensor(8.4007e-07, dtype=torch.float64)
# 26
# x - C - mixture - Norm tensor([[11.2948, 11.7225,  8.9228,  9.7101]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.3000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.29478806 11.72253434  8.92277496  9.71006504]]
# Cal C - shape (4, 1)
# C original [[11.294787 11.722534  8.922774  9.710065]]
# Cal B by Cal C
#  [[-7.10542736e-15]
#  [ 6.00000024e-01]
#  [ 3.00000012e-01]
#  [ 1.00000001e-01]]
# pred [[1.18450722e-06 5.99998669e-01 2.99997761e-01 1.00001416e-01]]
# sum of pred 0.9999990299442736
# pred [[1.18450837e-06 5.99999251e-01 2.99998052e-01 1.00001513e-01]]
# sum of pred 1.0000000000000002
# loss tensor(1.3573e-06, dtype=torch.float64)
# 27
# x - C - mixture - Norm tensor([[11.1121, 11.4972,  7.7999,  8.5554]])
# y - B - ratio tensor([[0.3500, 0.5000, 0.0500, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.11208873 11.49715912  7.79992707  8.55544276]]
# Cal C - shape (4, 1)
# C original [[11.112089 11.497159  7.799927  8.555443]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.5       ]
#  [0.05      ]
#  [0.1       ]]
# pred [[0.34999897 0.50000137 0.05000191 0.09999866]]
# sum of pred 1.0000009120306146
# pred [[0.34999865 0.50000091 0.05000187 0.09999857]]
# sum of pred 1.0
# loss tensor(1.3891e-06, dtype=torch.float64)
# 28
# x - C - mixture - Norm tensor([[11.5519, 11.9128,  8.9308, 10.1647]])
# y - B - ratio tensor([[0.0500, 0.7500, 0.1000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.55188714 11.91279714  8.93075271 10.1647483 ]]
# Cal C - shape (4, 1)
# C original [[11.5518875 11.912797   8.930753  10.164748 ]]
# Cal B by Cal C
#  [[0.05]
#  [0.75]
#  [0.1 ]
#  [0.1 ]]
# pred [[0.049999   0.75000136 0.10000191 0.09999866]]
# sum of pred 1.000000923579588
# pred [[0.04999895 0.75000067 0.10000182 0.09999856]]
# sum of pred 1.0
# loss tensor(1.2433e-06, dtype=torch.float64)
# 29
# x - C - mixture - Norm tensor([[10.6295, 11.0143,  7.4798,  7.9800]])
# y - B - ratio tensor([[0.3000, 0.4500, 0.2000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.62954602 11.01433964  7.47976708  7.98003631]]
# Cal C - shape (4, 1)
# C original [[10.629546  11.014339   7.4797673  7.9800363]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.44999999]
#  [0.2       ]
#  [0.05      ]]
# pred [[0.29999922 0.45000089 0.20000147 0.04999907]]
# sum of pred 1.0000006391598717
# pred [[0.29999902 0.4500006  0.20000134 0.04999903]]
# sum of pred 1.0
# loss tensor(9.7618e-07, dtype=torch.float64)
# 30
# x - C - mixture - Norm tensor([[11.2285, 11.9014,  9.2397,  8.8200]])
# y - B - ratio tensor([[0.0000, 0.1000, 0.7000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.22852774 11.90141607  9.23965316  8.82001293]]
# Cal C - shape (4, 1)
# C original [[11.228528 11.901416  9.239654  8.820013]]
# Cal B by Cal C
#  [[-3.55271368e-15]
#  [ 1.00000001e-01]
#  [ 6.99999988e-01]
#  [ 2.00000003e-01]]
# pred [[-1.20576484e-06  1.00001393e-01  7.00002152e-01  1.99998603e-01]]
# sum of pred 1.0000009423225897
# pred [[-1.20576370e-06  1.00001299e-01  7.00001493e-01  1.99998414e-01]]
# sum of pred 1.0
# loss tensor(1.3990e-06, dtype=torch.float64)
# 31
# x - C - mixture - Norm tensor([[11.6926, 12.1505,  9.3375, 10.2080]])
# y - B - ratio tensor([[0.0000, 0.6000, 0.2500, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.69261352 12.15050083  9.33745199 10.2079537 ]]
# Cal C - shape (4, 1)
# C original [[11.692614 12.1505    9.337452 10.207953]]
# Cal B by Cal C
#  [[0.        ]
#  [0.60000002]
#  [0.25      ]
#  [0.15000001]]
# pred [[-1.19268077e-06  6.00001557e-01  2.50002191e-01  1.49998482e-01]]
# sum of pred 1.0000010371882624
# pred [[-1.19267953e-06  6.00000934e-01  2.50001932e-01  1.49998326e-01]]
# sum of pred 1.0
# loss tensor(1.4287e-06, dtype=torch.float64)
# 32
# x - C - mixture - Norm tensor([[10.0277, 10.5533,  7.2668,  6.7710]])
# y - B - ratio tensor([[0.2500, 0.1000, 0.6000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.02768247 10.55325636  7.26679904  6.77102134]]
# Cal C - shape (4, 1)
# C original [[10.027682  10.553256   7.266799   6.7710214]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.1       ]
#  [0.60000002]
#  [0.05      ]]
# pred [[0.2499997  0.10000039 0.60000047 0.04999966]]
# sum of pred 1.0000002224524316
# pred [[0.24999964 0.10000037 0.60000034 0.04999965]]
# sum of pred 1.0
# loss tensor(3.4832e-07, dtype=torch.float64)
# 33
# x - C - mixture - Norm tensor([[10.8115, 11.3064,  6.9300,  6.8783]])
# y - B - ratio tensor([[0.6500, 0.1000, 0.1000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.81154257 11.30637237  6.93003585  6.87827721]]
# Cal C - shape (4, 1)
# C original [[10.8115425 11.306373   6.930036   6.8782773]]
# Cal B by Cal C
#  [[0.64999998]
#  [0.1       ]
#  [0.1       ]
#  [0.15000001]]
# pred [[0.65000047 0.09999923 0.09999911 0.15000071]]
# sum of pred 0.9999995251898675
# pred [[0.65000078 0.09999928 0.09999916 0.15000079]]
# sum of pred 1.0
# loss tensor(7.8617e-07, dtype=torch.float64)
# 34
# x - C - mixture - Norm tensor([[12.4463, 13.0188,  9.4507, 10.0923]])
# y - B - ratio tensor([[0.3000, 0.3500, 0.0500, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.44629155 13.01876236  9.45065744 10.09231403]]
# Cal C - shape (4, 1)
# C original [[12.446291 13.018762  9.450657 10.092314]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.34999999]
#  [0.05      ]
#  [0.30000001]]
# pred [[0.2999999  0.35000024 0.05000006 0.29999985]]
# sum of pred 1.0000000511283282
# pred [[0.29999988 0.35000022 0.05000006 0.29999983]]
# sum of pred 1.0
# loss tensor(1.4964e-07, dtype=torch.float64)
# 35
# x - C - mixture - Norm tensor([[13.4748, 14.2315, 11.3210, 11.7641]])
# y - B - ratio tensor([[0.0500, 0.2500, 0.2500, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.47475449 14.23151172 11.3210163  11.76413962]]
# Cal C - shape (4, 1)
# C original [[13.474754 14.231512 11.321016 11.76414 ]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.25      ]
#  [0.25      ]
#  [0.44999999]]
# pred [[0.05000106 0.24999873 0.2499979  0.45000137]]
# sum of pred 0.9999990480943737
# pred [[0.05000111 0.24999896 0.24999813 0.4500018 ]]
# sum of pred 1.0
# loss tensor(1.4538e-06, dtype=torch.float64)
# 36
# x - C - mixture - Norm tensor([[13.5609, 14.2992, 11.3723, 11.9527]])
# y - B - ratio tensor([[0.0500, 0.3000, 0.2000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.56094574 14.29921697 11.37226398 11.95272267]]
# Cal C - shape (4, 1)
# C original [[13.5609455 14.299217  11.372264  11.952723 ]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.30000001]
#  [0.2       ]
#  [0.44999999]]
# pred [[0.05000088 0.29999881 0.19999846 0.45000111]]
# sum of pred 0.9999992583942152
# pred [[0.05000092 0.29999904 0.1999986  0.45000144]]
# sum of pred 1.0
# loss tensor(1.1865e-06, dtype=torch.float64)
# 37
# x - C - mixture - Norm tensor([[12.3616, 12.9639,  9.5452, 10.0148]])
# y - B - ratio tensor([[0.2500, 0.3000, 0.1500, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.36157442 12.9639095   9.54517466 10.01479645]]
# Cal C - shape (4, 1)
# C original [[12.361574 12.963909  9.545175 10.014796]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.30000001]
#  [0.15000001]
#  [0.30000001]]
# pred [[0.24999973 0.30000027 0.15000047 0.29999973]]
# sum of pred 1.0000001935986873
# pred [[0.24999968 0.30000021 0.15000044 0.29999967]]
# sum of pred 1.0
# loss tensor(3.2281e-07, dtype=torch.float64)
# 38
# x - C - mixture - Norm tensor([[10.3268, 10.7312,  7.9909,  8.3371]])
# y - B - ratio tensor([[0.0000, 0.5000, 0.5000, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.32675449 10.73119069  7.99092542  8.33712156]]
# Cal C - shape (4, 1)
# C original [[10.326755  10.731191   7.9909253  8.337122 ]]
# Cal B by Cal C
#  [[-3.55271368e-15]
#  [ 5.00000000e-01]
#  [ 5.00000000e-01]
#  [ 0.00000000e+00]]
# pred [[4.27022897e-08 5.00000165e-01 4.99999765e-01 3.02707193e-09]]
# sum of pred 0.9999999755935356
# pred [[4.27022907e-08 5.00000177e-01 4.99999777e-01 3.02707200e-09]]
# sum of pred 1.0
# loss tensor(1.1153e-07, dtype=torch.float64)
# 39
# x - C - mixture - Norm tensor([[10.6354, 11.0657,  8.0628,  8.4243]])
# y - B - ratio tensor([[0.1000, 0.4500, 0.4000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.63544122 11.06574791  8.06282561  8.42429693]]
# Cal C - shape (4, 1)
# C original [[10.635441 11.065748  8.062825  8.424297]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.44999999]
#  [0.40000001]
#  [0.05      ]]
# pred [[0.10000162 0.44999816 0.39999686 0.05000198]]
# sum of pred 0.9999986285626292
# pred [[0.10000176 0.44999878 0.39999741 0.05000205]]
# sum of pred 0.9999999999999999
# loss tensor(1.9017e-06, dtype=torch.float64)
# 40
# x - C - mixture - Norm tensor([[10.7239, 11.2258,  6.7330,  6.5786]])
# y - B - ratio tensor([[0.7000, 0.0500, 0.1000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.72387777 11.22581531  6.7330237   6.57862919]]
# Cal C - shape (4, 1)
# C original [[10.723878  11.225815   6.7330236  6.578629 ]]
# Cal B by Cal C
#  [[0.69999999]
#  [0.05      ]
#  [0.1       ]
#  [0.15000001]]
# pred [[0.69999882 0.05000154 0.10000212 0.1499985 ]]
# sum of pred 1.0000009906485907
# pred [[0.69999813 0.05000149 0.10000203 0.14999835]]
# sum of pred 1.0
# loss tensor(1.7552e-06, dtype=torch.float64)
# 41
# x - C - mixture - Norm tensor([[10.4947, 10.8280,  7.6561,  8.3811]])
# y - B - ratio tensor([[0.1500, 0.6000, 0.2500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.49471553 10.82804493  7.65612685  8.38109216]]
# Cal C - shape (4, 1)
# C original [[10.494715  10.828045   7.6561265  8.381092 ]]
# Cal B by Cal C
#  [[1.50000006e-01]
#  [6.00000024e-01]
#  [2.50000000e-01]
#  [3.55271368e-15]]
# pred [[1.50001479e-01 5.99998073e-01 2.49997197e-01 1.93226601e-06]]
# sum of pred 0.9999986811281687
# pred [[1.50001677e-01 5.99998864e-01 2.49997526e-01 1.93226856e-06]]
# sum of pred 0.9999999999999999
# loss tensor(1.8092e-06, dtype=torch.float64)
# 42
# x - C - mixture - Norm tensor([[12.6474, 13.4779, 10.7959, 10.4344]])
# y - B - ratio tensor([[0.0000, 0.0000, 0.6000, 0.4000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.64744792 13.47787241 10.79586656 10.43440203]]
# Cal C - shape (4, 1)
# C original [[12.647448  13.477872  10.795866  10.4344015]]
# Cal B by Cal C
#  [[-3.55271368e-15]
#  [ 0.00000000e+00]
#  [ 6.00000024e-01]
#  [ 4.00000006e-01]]
# pred [[-1.91067329e-07  3.50223019e-07  6.00000423e-01  3.99999649e-01]]
# sum of pred 1.000000230776564
# pred [[-1.91067285e-07  3.50222938e-07  6.00000284e-01  3.99999556e-01]]
# sum of pred 1.0
# loss tensor(3.1283e-07, dtype=torch.float64)
# 43
# x - C - mixture - Norm tensor([[12.1391, 12.6971,  9.5245, 10.1162]])
# y - B - ratio tensor([[0.1500, 0.4000, 0.2000, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.13907849 12.69705706  9.52452176 10.11620367]]
# Cal C - shape (4, 1)
# C original [[12.139078 12.697057  9.524522 10.116203]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.40000001]
#  [0.2       ]
#  [0.25      ]]
# pred [[0.14999989 0.39999989 0.20000025 0.24999999]]
# sum of pred 1.000000011999127
# pred [[0.14999989 0.39999988 0.20000025 0.24999998]]
# sum of pred 1.0
# loss tensor(1.2505e-07, dtype=torch.float64)
# 44
# x - C - mixture - Norm tensor([[ 9.6181, 10.0225,  5.6860,  5.3846]])
# y - B - ratio tensor([[0.6500, 0.1000, 0.2500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.61806597 10.02247266  5.68600459  5.38461112]]
# Cal C - shape (4, 1)
# C original [[ 9.618066  10.022473   5.6860046  5.384611 ]]
# Cal B by Cal C
#  [[6.49999976e-01]
#  [1.00000001e-01]
#  [2.50000000e-01]
#  [3.55271368e-15]]
# pred [[6.50001471e-01 9.99979959e-02 2.49997377e-01 1.89600757e-06]]
# sum of pred 0.9999987393955614
# pred [[6.50002290e-01 9.99981219e-02 2.49997692e-01 1.89600996e-06]]
# sum of pred 1.0
# loss tensor(2.0994e-06, dtype=torch.float64)
# 45
# x - C - mixture - Norm tensor([[ 9.7175, 10.2058,  7.0491,  6.5728]])
# y - B - ratio tensor([[0.2000, 0.1500, 0.6500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.71752149 10.20584659  7.04913386  6.57278049]]
# Cal C - shape (4, 1)
# C original [[ 9.717522  10.205847   7.049134   6.5727806]]
# Cal B by Cal C
#  [[ 2.00000003e-01]
#  [ 1.50000006e-01]
#  [ 6.49999976e-01]
#  [-3.55271368e-15]]
# pred [[2.00000173e-01 1.49999940e-01 6.49999681e-01 1.21113878e-07]]
# sum of pred 0.9999999144087006
# pred [[2.00000190e-01 1.49999952e-01 6.49999737e-01 1.21113888e-07]]
# sum of pred 0.9999999999999999
# loss tensor(1.5019e-07, dtype=torch.float64)
# 46
# x - C - mixture - Norm tensor([[11.8245, 12.3111,  8.8696,  9.5848]])
# y - B - ratio tensor([[0.2500, 0.4500, 0.1000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.82449623 12.31109122  8.86956285  9.58476743]]
# Cal C - shape (4, 1)
# C original [[11.824496 12.311091  8.869563  9.584767]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.44999999]
#  [0.1       ]
#  [0.2       ]]
# pred [[0.25000012 0.44999966 0.09999988 0.20000022]]
# sum of pred 0.9999998726198918
# pred [[0.25000015 0.44999971 0.09999989 0.20000025]]
# sum of pred 1.0
# loss tensor(1.9461e-07, dtype=torch.float64)
# 47
# x - C - mixture - Norm tensor([[11.8717, 12.4168,  8.4962,  8.8841]])
# y - B - ratio tensor([[0.4500, 0.2500, 0.0500, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.87166207 12.41682902  8.49619112  8.88406383]]
# Cal C - shape (4, 1)
# C original [[11.871662 12.416829  8.496191  8.884064]]
# Cal B by Cal C
#  [[0.44999999]
#  [0.25      ]
#  [0.05      ]
#  [0.25      ]]
# pred [[0.45000009 0.24999993 0.0499999  0.25000005]]
# sum of pred 0.9999999652771443
# pred [[0.4500001  0.24999994 0.0499999  0.25000006]]
# sum of pred 1.0
# loss tensor(8.4356e-08, dtype=torch.float64)
# 48
# x - C - mixture - Norm tensor([[11.6580, 12.2271,  9.3501,  9.6519]])
# y - B - ratio tensor([[0.0500, 0.3500, 0.4000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.65800944 12.22708951  9.35012637  9.65186235]]
# Cal C - shape (4, 1)
# C original [[11.65801  12.22709   9.350126  9.651862]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.34999999]
#  [0.40000001]
#  [0.2       ]]
# pred [[0.05000058 0.34999928 0.39999912 0.20000063]]
# sum of pred 0.9999996147509478
# pred [[0.0500006  0.34999942 0.39999927 0.20000071]]
# sum of pred 1.0
# loss tensor(6.5414e-07, dtype=torch.float64)
# 49
# x - C - mixture - Norm tensor([[11.6205, 12.2780,  9.0713,  8.8736]])
# y - B - ratio tensor([[0.2000, 0.1000, 0.4500, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.62045794 12.27797422  9.07127162  8.87364091]]
# Cal C - shape (4, 1)
# C original [[11.620458 12.277974  9.071272  8.873641]]
# Cal B by Cal C
#  [[0.2       ]
#  [0.1       ]
#  [0.44999999]
#  [0.25      ]]
# pred [[0.20000014 0.09999958 0.44999963 0.25000038]]
# sum of pred 0.9999997242261642
# pred [[0.2000002  0.0999996  0.44999976 0.25000044]]
# sum of pred 1.0
# loss tensor(3.1645e-07, dtype=torch.float64)
# 50
# x - C - mixture - Norm tensor([[10.4129, 10.7989,  8.0422,  8.5257]])
# y - B - ratio tensor([[0.0000, 0.5500, 0.4500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.4129456  10.79889579  8.04217299  8.52570452]]
# Cal C - shape (4, 1)
# C original [[10.412946 10.798896  8.042173  8.525704]]
# Cal B by Cal C
#  [[-3.55271368e-15]
#  [ 5.50000012e-01]
#  [ 4.49999988e-01]
#  [-3.55271368e-15]]
# pred [[-4.67206586e-07  5.50000360e-01  4.50000936e-01 -4.77470774e-07]]
# sum of pred 1.0000003520675698
# pred [[-4.67206422e-07  5.50000167e-01  4.50000778e-01 -4.77470606e-07]]
# sum of pred 1.0
# loss tensor(4.7234e-07, dtype=torch.float64)
# 51
# x - C - mixture - Norm tensor([[11.4222, 11.8446,  8.0176,  8.7537]])
# y - B - ratio tensor([[0.4000, 0.4500, 0.0000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.42224937 11.84456853  8.01759195  8.75368335]]
# Cal C - shape (4, 1)
# C original [[11.42225  11.844568  8.017591  8.753683]]
# Cal B by Cal C
#  [[0.40000001]
#  [0.44999999]
#  [0.        ]
#  [0.15000001]]
# pred [[3.99999027e-01 4.50001628e-01 1.90569252e-06 1.49998472e-01]]
# sum of pred 1.0000010325251658
# pred [[3.99998614e-01 4.50001163e-01 1.90569055e-06 1.49998317e-01]]
# sum of pred 1.0
# loss tensor(1.5405e-06, dtype=torch.float64)
# 52
# x - C - mixture - Norm tensor([[13.1285, 13.9478, 10.9703, 10.8987]])
# y - B - ratio tensor([[0.1000, 0.0500, 0.4000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.1285164  13.94783936 10.97026149 10.89874288]]
# Cal C - shape (4, 1)
# C original [[13.128516 13.94784  10.970262 10.898743]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.05      ]
#  [0.40000001]
#  [0.44999999]]
# pred [[0.10000095 0.04999859 0.3999984  0.45000124]]
# sum of pred 0.9999991809210513
# pred [[0.10000103 0.04999863 0.39999873 0.45000161]]
# sum of pred 1.0
# loss tensor(1.3246e-06, dtype=torch.float64)
# 53
# x - C - mixture - Norm tensor([[11.9336, 12.6511,  9.5805,  9.2940]])
# y - B - ratio tensor([[0.1500, 0.0500, 0.5000, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.9335665  12.65108811  9.58046604  9.29401211]]
# Cal C - shape (4, 1)
# C original [[11.933566 12.651088  9.580466  9.294012]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.05      ]
#  [0.5       ]
#  [0.30000001]]
# pred [[0.14999984 0.04999991 0.50000018 0.30000004]]
# sum of pred 0.9999999688360361
# pred [[0.14999985 0.04999991 0.50000019 0.30000005]]
# sum of pred 1.0
# loss tensor(1.1820e-07, dtype=torch.float64)
# 54
# x - C - mixture - Norm tensor([[ 9.9371, 10.4470,  6.7783,  6.2492]])
# y - B - ratio tensor([[0.4000, 0.0500, 0.5000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.93706975 10.44699483  6.77825741  6.24924281]]
# Cal C - shape (4, 1)
# C original [[ 9.93707   10.446995   6.7782574  6.249243 ]]
# Cal B by Cal C
#  [[0.40000001]
#  [0.05      ]
#  [0.5       ]
#  [0.05      ]]
# pred [[0.3999997  0.05000046 0.50000058 0.04999957]]
# sum of pred 1.0000003042413574
# pred [[0.39999958 0.05000044 0.50000043 0.04999955]]
# sum of pred 1.0
# loss tensor(4.3513e-07, dtype=torch.float64)
# 55
# x - C - mixture - Norm tensor([[12.4058, 13.0439,  8.8803,  9.0920]])
# y - B - ratio tensor([[0.5500, 0.1000, 0.0000, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.40579229 13.04394277  8.8802733   9.09196212]]
# Cal C - shape (4, 1)
# C original [[12.405792 13.043942  8.880273  9.091962]]
# Cal B by Cal C
#  [[5.50000012e-01]
#  [1.00000001e-01]
#  [7.10542736e-15]
#  [3.49999994e-01]]
# pred [[5.49999725e-01 1.00000568e-01 5.53610136e-07 3.49999481e-01]]
# sum of pred 1.0000003283148402
# pred [[5.49999545e-01 1.00000536e-01 5.53609954e-07 3.49999366e-01]]
# sum of pred 1.0
# loss tensor(5.4569e-07, dtype=torch.float64)
# 56
# x - C - mixture - Norm tensor([[13.7017, 14.5369, 11.7790, 11.9959]])
# y - B - ratio tensor([[0.0000, 0.1500, 0.3500, 0.5000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.70167184 14.53692038 11.77896307 11.99592784]]
# Cal C - shape (4, 1)
# C original [[13.701672 14.536921 11.778963 11.995928]]
# Cal B by Cal C
#  [[0.        ]
#  [0.15000001]
#  [0.34999999]
#  [0.5       ]]
# pred [[6.90840633e-07 1.49999010e-01 3.49998736e-01 5.00000935e-01]]
# sum of pred 0.9999993720028577
# pred [[6.90841067e-07 1.49999105e-01 3.49998956e-01 5.00001249e-01]]
# sum of pred 1.0
# loss tensor(9.6993e-07, dtype=torch.float64)
# 57
# x - C - mixture - Norm tensor([[10.1382, 10.4544,  6.2850,  6.7382]])
# y - B - ratio tensor([[0.5500, 0.4000, 0.0500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.13816051 10.45440776  6.28501941  6.73823909]]
# Cal C - shape (4, 1)
# C original [[10.138161  10.454408   6.2850194  6.738239 ]]
# Cal B by Cal C
#  [[0.55000001]
#  [0.40000001]
#  [0.05      ]
#  [0.        ]]
# pred [[ 5.49999500e-01  4.00000654e-01  5.00010723e-02 -7.09806876e-07]]
# sum of pred 1.0000005160689653
# pred [[ 5.49999216e-01  4.00000447e-01  5.00010464e-02 -7.09806510e-07]]
# sum of pred 0.9999999999999999
# loss tensor(7.4815e-07, dtype=torch.float64)
# 58
# x - C - mixture - Norm tensor([[10.8963, 11.3612,  6.8355,  6.9558]])
# y - B - ratio tensor([[0.7000, 0.1500, 0.0000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.89625998 11.36122552  6.83551885  6.95579504]]
# Cal C - shape (4, 1)
# C original [[10.89626  11.361225  6.835519  6.955795]]
# Cal B by Cal C
#  [[ 6.99999988e-01]
#  [ 1.50000006e-01]
#  [-7.10542736e-15]
#  [ 1.50000006e-01]]
# pred [[6.99998718e-01 1.50001676e-01 2.38784292e-06 1.49998340e-01]]
# sum of pred 1.0000011216497953
# pred [[6.99997933e-01 1.50001508e-01 2.38784024e-06 1.49998172e-01]]
# sum of pred 1.0
# loss tensor(1.9449e-06, dtype=torch.float64)
# 59
# x - C - mixture - Norm tensor([[13.4402, 14.3081, 11.3337, 11.2080]])
# y - B - ratio tensor([[0.1000, 0.0000, 0.4000, 0.5000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.44015101 14.30810102 11.33369117 11.20804882]]
# Cal C - shape (4, 1)
# C original [[13.440151 14.308101 11.333691 11.208049]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.        ]
#  [0.40000001]
#  [0.5       ]]
# pred [[9.99994134e-02 1.17822395e-06 4.00001045e-01 4.99999009e-01]]
# sum of pred 1.0000006455168204
# pred [[9.99993489e-02 1.17822319e-06 4.00000786e-01 4.99998687e-01]]
# sum of pred 1.0
# loss tensor(9.8115e-07, dtype=torch.float64)
# 60
# x - C - mixture - Norm tensor([[ 9.8538, 10.4050,  7.0185,  6.2828]])
# y - B - ratio tensor([[0.3000, 0.0000, 0.6500, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.85382612 10.40499372  7.01853897  6.28279009]]
# Cal C - shape (4, 1)
# C original [[ 9.8538265 10.404994   7.018539   6.28279  ]]
# Cal B by Cal C
#  [[3.00000012e-01]
#  [3.55271368e-15]
#  [6.49999976e-01]
#  [5.00000007e-02]]
# pred [[2.99999937e-01 2.70085540e-07 6.50000198e-01 4.99997702e-02]]
# sum of pred 1.0000001753068943
# pred [[2.99999884e-01 2.70085492e-07 6.50000084e-01 4.99997614e-02]]
# sum of pred 1.0
# loss tensor(1.8618e-07, dtype=torch.float64)
# 61
# x - C - mixture - Norm tensor([[12.7248, 13.4685,  9.9725,  9.9566]])
# y - B - ratio tensor([[0.3000, 0.0500, 0.2500, 0.4000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.72479599 13.46846486  9.97252617  9.95659387]]
# Cal C - shape (4, 1)
# C original [[12.724795  13.468465   9.972526   9.9565935]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.05      ]
#  [0.25      ]
#  [0.40000001]]
# pred [[0.30000138 0.0499983  0.24999753 0.40000166]]
# sum of pred 0.9999988733008998
# pred [[0.30000172 0.04999836 0.24999781 0.40000211]]
# sum of pred 1.0
# loss tensor(1.9087e-06, dtype=torch.float64)
# 62
# x - C - mixture - Norm tensor([[10.3349, 10.8750,  7.1929,  6.7471]])
# y - B - ratio tensor([[0.4000, 0.0500, 0.4500, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.33489515 10.87496125  7.19293439  6.74713141]]
# Cal C - shape (4, 1)
# C original [[10.334895  10.874961   7.1929345  6.7471313]]
# Cal B by Cal C
#  [[0.40000001]
#  [0.05      ]
#  [0.44999999]
#  [0.1       ]]
# pred [[0.39999925 0.05000087 0.45000133 0.09999912]]
# sum of pred 1.0000005725550736
# pred [[0.39999902 0.05000084 0.45000107 0.09999907]]
# sum of pred 1.0
# loss tensor(9.6235e-07, dtype=torch.float64)
# 63
# x - C - mixture - Norm tensor([[11.4437, 12.1040,  8.5315,  8.1633]])
# y - B - ratio tensor([[0.3500, 0.0000, 0.4000, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.44365438 12.10400787  8.53148268  8.16327968]]
# Cal C - shape (4, 1)
# C original [[11.443654 12.104008  8.531483  8.16328 ]]
# Cal B by Cal C
#  [[ 3.49999994e-01]
#  [-3.55271368e-15]
#  [ 4.00000006e-01]
#  [ 2.50000000e-01]]
# pred [[ 3.50000201e-01 -4.27530516e-07  3.99999606e-01  2.50000362e-01]]
# sum of pred 0.9999997405144789
# pred [[ 3.50000292e-01 -4.27530627e-07  3.99999709e-01  2.50000427e-01]]
# sum of pred 1.0
# loss tensor(3.6202e-07, dtype=torch.float64)
# 64
# x - C - mixture - Norm tensor([[11.8385, 12.5063,  8.6546,  8.4390]])
# y - B - ratio tensor([[0.4500, 0.0000, 0.2500, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.83853233 12.50627033  8.65463057  8.43903815]]
# Cal C - shape (4, 1)
# C original [[11.838532 12.50627   8.654631  8.439038]]
# Cal B by Cal C
#  [[ 4.49999988e-01]
#  [-7.10542736e-15]
#  [ 2.50000000e-01]
#  [ 3.00000012e-01]]
# pred [[4.49999930e-01 9.10539342e-08 2.50000089e-01 2.99999943e-01]]
# sum of pred 1.0000000531152402
# pred [[4.49999906e-01 9.10539293e-08 2.50000076e-01 2.99999927e-01]]
# sum of pred 1.0
# loss tensor(8.3565e-08, dtype=torch.float64)
# 65
# x - C - mixture - Norm tensor([[10.1109, 10.5953,  7.0265,  6.7375]])
# y - B - ratio tensor([[0.3500, 0.1500, 0.4500, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.11092557 10.59525691  7.02651706  6.73747371]]
# Cal C - shape (4, 1)
# C original [[10.110926 10.595257  7.026517  6.737474]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.15000001]
#  [0.44999999]
#  [0.05      ]]
# pred [[0.3499998  0.15000047 0.45000024 0.04999968]]
# sum of pred 1.000000185212702
# pred [[0.34999973 0.15000044 0.45000016 0.04999967]]
# sum of pred 1.0
# loss tensor(3.0040e-07, dtype=torch.float64)
# 66
# x - C - mixture - Norm tensor([[10.9139, 11.5155,  8.5847,  8.2886]])
# y - B - ratio tensor([[0.1000, 0.1500, 0.6000, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.91394615 11.51545093  8.58469474  8.28857719]]
# Cal C - shape (4, 1)
# C original [[10.913946  11.5154505  8.584695   8.288577 ]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.15000001]
#  [0.60000002]
#  [0.15000001]]
# pred [[0.09999902 0.15000116 0.60000178 0.14999884]]
# sum of pred 1.0000008029433367
# pred [[0.09999894 0.15000104 0.6000013  0.14999872]]
# sum of pred 1.0
# loss tensor(1.1657e-06, dtype=torch.float64)
# 67
# x - C - mixture - Norm tensor([[10.3238, 10.7055,  7.6994,  8.1150]])
# y - B - ratio tensor([[0.1000, 0.5000, 0.4000, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.32380693 10.70548659  7.6993962   8.11499129]]
# Cal C - shape (4, 1)
# C original [[10.323807 10.705486  7.699396  8.114991]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.5       ]
#  [0.40000001]
#  [0.        ]]
# pred [[ 9.99997382e-02  5.00000302e-01  4.00000441e-01 -2.96974271e-07]]
# sum of pred 1.0000001838266215
# pred [[ 9.99997198e-02  5.00000210e-01  4.00000367e-01 -2.96974216e-07]]
# sum of pred 1.0
# loss tensor(2.8745e-07, dtype=torch.float64)
# 68
# x - C - mixture - Norm tensor([[ 9.9238, 10.3313,  5.4664,  5.2497]])
# y - B - ratio tensor([[0.8500, 0.0500, 0.0500, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.92380557 10.33132623  5.46637576  5.24965644]]
# Cal C - shape (4, 1)
# C original [[ 9.923805 10.331326  5.466376  5.249656]]
# Cal B by Cal C
#  [[0.85000002]
#  [0.05      ]
#  [0.05      ]
#  [0.05      ]]
# pred [[0.84999912 0.05000094 0.05000156 0.04999902]]
# sum of pred 1.0000006418324823
# pred [[0.84999857 0.05000091 0.05000153 0.04999899]]
# sum of pred 1.0
# loss tensor(1.2252e-06, dtype=torch.float64)
# 69
# x - C - mixture - Norm tensor([[12.8485, 13.4853, 10.3026, 10.9234]])
# y - B - ratio tensor([[0.1500, 0.3500, 0.1500, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.84853818 13.48528481 10.30262814 10.92339789]]
# Cal C - shape (4, 1)
# C original [[12.848538  13.485285  10.3026285 10.923398 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.34999999]
#  [0.15000001]
#  [0.34999999]]
# pred [[0.1499994  0.35000064 0.1500011  0.34999933]]
# sum of pred 1.0000004639791413
# pred [[0.14999933 0.35000047 0.15000103 0.34999917]]
# sum of pred 1.0
# loss tensor(7.5266e-07, dtype=torch.float64)
# 70
# x - C - mixture - Norm tensor([[12.3601, 12.9511,  9.3994,  9.9037]])
# y - B - ratio tensor([[0.3000, 0.3000, 0.1000, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.36010067 12.95105749  9.39941005  9.90373131]]
# Cal C - shape (4, 1)
# C original [[12.3601   12.951057  9.399409  9.903731]]
# Cal B by Cal C
#  [[0.30000001]
#  [0.30000001]
#  [0.1       ]
#  [0.30000001]]
# pred [[0.30000191 0.29999779 0.09999635 0.30000234]]
# sum of pred 0.9999983937248373
# pred [[0.30000239 0.29999827 0.09999651 0.30000283]]
# sum of pred 1.0
# loss tensor(2.6051e-06, dtype=torch.float64)
# 71
# x - C - mixture - Norm tensor([[14.8951, 15.8208, 13.0230, 13.4896]])
# y - B - ratio tensor([[0.0000, 0.1500, 0.2000, 0.6500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[14.89514799 15.82081962 13.02299392 13.48959349]]
# Cal C - shape (4, 1)
# C original [[14.895148  15.82082   13.022994  13.4895935]]
# Cal B by Cal C
#  [[0.        ]
#  [0.15000001]
#  [0.2       ]
#  [0.64999998]]
# pred [[-1.06154005e-07  1.50000157e-01  2.00000287e-01  6.49999799e-01]]
# sum of pred 1.0000001364222157
# pred [[-1.06153990e-07  1.50000136e-01  2.00000260e-01  6.49999710e-01]]
# sum of pred 1.0
# loss tensor(1.8973e-07, dtype=torch.float64)
# 72
# x - C - mixture - Norm tensor([[13.0769, 13.8035, 10.9063, 11.2663]])
# y - B - ratio tensor([[0.0500, 0.2500, 0.3000, 0.4000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.07692942 13.80354564 10.90633962 11.26625133]]
# Cal C - shape (4, 1)
# C original [[13.076929 13.803545 10.90634  11.266252]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.25      ]
#  [0.30000001]
#  [0.40000001]]
# pred [[0.04999935 0.25000078 0.30000091 0.39999935]]
# sum of pred 1.0000003930585457
# pred [[0.04999933 0.25000068 0.3000008  0.39999919]]
# sum of pred 1.0
# loss tensor(7.3589e-07, dtype=torch.float64)
# 73
# x - C - mixture - Norm tensor([[12.9318, 13.5273, 10.0623, 10.8899]])
# y - B - ratio tensor([[0.2500, 0.4000, 0.0000, 0.3500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.93178165 13.52728575 10.06234645 10.88985053]]
# Cal C - shape (4, 1)
# C original [[12.931782 13.527286 10.062346 10.889851]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.40000001]
#  [0.        ]
#  [0.34999999]]
# pred [[2.49999497e-01 4.00000715e-01 8.69717532e-07 3.49999346e-01]]
# sum of pred 1.0000004267393834
# pred [[2.49999390e-01 4.00000544e-01 8.69717161e-07 3.49999196e-01]]
# sum of pred 1.0
# loss tensor(7.0378e-07, dtype=torch.float64)
# 74
# x - C - mixture - Norm tensor([[11.0444, 11.6632,  7.9710,  7.5543]])
# y - B - ratio tensor([[0.4000, 0.0000, 0.4000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.04435523 11.66318942  7.97104109  7.55432595]]
# Cal C - shape (4, 1)
# C original [[11.044355 11.663189  7.971041  7.554326]]
# Cal B by Cal C
#  [[0.40000001]
#  [0.        ]
#  [0.40000001]
#  [0.2       ]]
# pred [[3.99998754e-01 1.62113030e-06 4.00002183e-01 1.99998466e-01]]
# sum of pred 1.0000010245350737
# pred [[3.99998344e-01 1.62112864e-06 4.00001774e-01 1.99998261e-01]]
# sum of pred 1.0
# loss tensor(1.6981e-06, dtype=torch.float64)
# 75
# x - C - mixture - Norm tensor([[10.8535, 11.2940,  7.6462,  7.9897]])
# y - B - ratio tensor([[0.3500, 0.3500, 0.2000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.85351543 11.29404381  7.64618437  7.98969399]]
# Cal C - shape (4, 1)
# C original [[10.853516  11.294044   7.6461844  7.989694 ]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.34999999]
#  [0.2       ]
#  [0.1       ]]
# pred [[0.34999913 0.35000116 0.20000152 0.09999891]]
# sum of pred 1.0000007155288202
# pred [[0.34999888 0.35000091 0.20000137 0.09999884]]
# sum of pred 0.9999999999999999
# loss tensor(1.1432e-06, dtype=torch.float64)
# 76
# x - C - mixture - Norm tensor([[11.2071, 11.6420,  8.7258,  9.4104]])
# y - B - ratio tensor([[0.0500, 0.5500, 0.3000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.20712303 11.64197704  8.72576267  9.41041686]]
# Cal C - shape (4, 1)
# C original [[11.207123 11.641976  8.725762  9.410417]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.55000001]
#  [0.30000001]
#  [0.1       ]]
# pred [[0.04999921 0.55000108 0.30000139 0.09999898]]
# sum of pred 1.0000006615772001
# pred [[0.04999918 0.55000072 0.30000119 0.09999892]]
# sum of pred 1.0
# loss tensor(9.4793e-07, dtype=torch.float64)
# 77
# x - C - mixture - Norm tensor([[14.3536, 15.1294, 11.9101, 12.7264]])
# y - B - ratio tensor([[0.1500, 0.3000, 0.0000, 0.5500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[14.35364953 15.12944632 11.91008919 12.72637006]]
# Cal C - shape (4, 1)
# C original [[14.353649 15.129446 11.910089 12.72637 ]]
# Cal B by Cal C
#  [[1.50000006e-01]
#  [3.00000012e-01]
#  [7.10542736e-15]
#  [5.50000012e-01]]
# pred [[ 1.50000485e-01  2.99999642e-01 -9.23098156e-07  5.50000470e-01]]
# sum of pred 0.9999996731344751
# pred [[ 1.50000534e-01  2.99999740e-01 -9.23098458e-07  5.50000649e-01]]
# sum of pred 1.0
# loss tensor(5.8999e-07, dtype=torch.float64)
# 78
# x - C - mixture - Norm tensor([[10.3754, 10.8498,  7.7633,  7.7475]])
# y - B - ratio tensor([[0.1500, 0.3000, 0.5000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.37539439 10.84978082  7.76331848  7.74748327]]
# Cal C - shape (4, 1)
# C original [[10.375394  10.849781   7.7633185  7.7474833]]
# ...
# y - B - ratio tensor([[0.2500, 0.3500, 0.0000, 0.4000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.24341613 13.88754727 10.42577603 11.19915636]]
# Cal C - shape (4, 1)
# C original [[ 8.91961  13.747196 13.852031 11.917976]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.34999999]
#  [0.        ]
#  [0.40000001]]
# pred [[ 4.99588832 -9.28585801 -9.68208953  9.0301474 ]]
# sum of pred -4.9419118228586605
# pred [[-1.01092219  1.87900115  1.95917893 -1.8272579 ]]
# sum of pred 1.0
# loss tensor(1.7441, dtype=torch.float64)
# 335
# x - C - mixture - Norm tensor([[10.9154,  8.9004,  7.8784,  4.8773]])
# y - B - ratio tensor([[0.2000, 0.1500, 0.6500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.71752149 10.20584659  7.04913386  6.57278049]]
# Cal C - shape (4, 1)
# C original [[10.915449   8.900392   7.8783774  4.8772535]]
# Cal B by Cal C
#  [[ 2.00000003e-01]
#  [ 1.50000006e-01]
#  [ 6.49999976e-01]
#  [-3.55271368e-15]]
# pred [[-5.32185517  6.60583667 11.40767676 -6.93133661]]
# sum of pred 5.760321652663784
# pred [[-0.9238816   1.14678261  1.98038885 -1.20328986]]
# sum of pred 1.0
# loss tensor(1.1636, dtype=torch.float64)
# 336
# x - C - mixture - Norm tensor([[14.0294,  9.6478,  9.1106, 11.3666]])
# y - B - ratio tensor([[0.2000, 0.3000, 0.3500, 0.1500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.16957157 11.6928618   8.44690797  8.63219546]]
# Cal C - shape (4, 1)
# C original [[14.029416  9.647831  9.110615 11.366596]]
# Cal B by Cal C
#  [[0.2       ]
#  [0.30000001]
#  [0.34999999]
#  [0.15000001]]
# pred [[ -8.23455556  12.49076966  14.71639106 -10.75220187]]
# sum of pred 8.220403291188628
# pred [[-1.0017216   1.5194838   1.79022738 -1.30798958]]
# sum of pred 1.0
# loss tensor(1.3299, dtype=torch.float64)
# 337
# x - C - mixture - Norm tensor([[10.5101, 13.2446,  9.2744, 10.7288]])
# y - B - ratio tensor([[0.3500, 0.2000, 0.2000, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.78841873 12.37482822  8.73647291  8.91761132]]
# Cal C - shape (4, 1)
# C original [[10.510066 13.244606  9.274443 10.728788]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.2       ]
#  [0.2       ]
#  [0.25      ]]
# pred [[ 4.25031303 -5.07540173 -7.72124355  5.75581776]]
# sum of pred -2.7905144938595825
# pred [[-1.52312881  1.81880501  2.76696056 -2.06263675]]
# sum of pred 1.0
# loss tensor(2.0929, dtype=torch.float64)
# 338
# x - C - mixture - Norm tensor([[8.0732, 9.4643, 4.4557, 6.2669]])
# y - B - ratio tensor([[0.6000, 0.4000, 0.0000, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.1366868  10.44155578  6.13925482  6.62717397]]
# Cal C - shape (4, 1)
# C original [[8.073237 9.464286 4.455738 6.266863]]
# Cal B by Cal C
#  [[0.60000002]
#  [0.40000001]
#  [0.        ]
#  [0.        ]]
# pred [[ 3.24101224 -2.6604882  -5.24313895  3.26529732]]
# sum of pred -1.3973175826279842
# pred [[-2.31945284  1.90399679  3.75228868 -2.33683263]]
# sum of pred 1.0
# loss tensor(2.6281, dtype=torch.float64)
# 339
# x - C - mixture - Norm tensor([[9.5640, 9.0394, 6.4437, 9.6610]])
# y - B - ratio tensor([[0.4500, 0.1000, 0.4500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.62396124 10.073881    6.2690631   5.82887174]]
# Cal C - shape (4, 1)
# C original [[9.563991 9.039362 6.443696 9.661044]]
# Cal B by Cal C
#  [[4.49999988e-01]
#  [1.00000001e-01]
#  [4.49999988e-01]
#  [3.55271368e-15]]
# pred [[-0.5510903   2.39560414  0.46992519 -0.94640474]]
# sum of pred 1.368034296675468
# pred [[-0.40283369  1.75112872  0.34350396 -0.69179899]]
# sum of pred 1.0
# loss tensor(0.8256, dtype=torch.float64)
# 340
# x - C - mixture - Norm tensor([[12.3559,  8.8332,  3.5407,  8.4383]])
# y - B - ratio tensor([[0.0500, 0.2500, 0.6000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.68997649 11.2357465   8.41827732  8.27891937]]
# Cal C - shape (4, 1)
# C original [[12.355921   8.8331785  3.540689   8.438311 ]]
# Cal B by Cal C
#  [[0.05      ]
#  [0.25      ]
#  [0.60000002]
#  [0.1       ]]
# pred [[-3.9037294   9.22819528  7.49620286 -7.1758222 ]]
# sum of pred 5.644846540767013
# pred [[-0.69155634  1.63480003  1.32797283 -1.27121652]]
# sum of pred 1.0000000000000002
# loss tensor(1.0564, dtype=torch.float64)
# 341
# x - C - mixture - Norm tensor([[10.6731, 12.6157,  8.3968,  9.5910]])
# y - B - ratio tensor([[0.0500, 0.8000, 0.1500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.84242739 11.12456932  8.15264628  9.35755401]]
# Cal C - shape (4, 1)
# C original [[10.673054 12.615703  8.396763  9.590962]]
# Cal B by Cal C
#  [[5.00000007e-02]
#  [8.00000012e-01]
#  [1.50000006e-01]
#  [3.55271368e-15]]
# pred [[ 3.08402793 -3.26525739 -5.2242223   3.87768017]]
# sum of pred -1.527771598455864
# pred [[-2.01864463  2.13726803  3.41950479 -2.53812819]]
# sum of pred 1.0
# loss tensor(2.3034, dtype=torch.float64)
# 342
# x - C - mixture - Norm tensor([[ 9.8791, 13.7588,  7.7388,  8.7346]])
# y - B - ratio tensor([[0.3500, 0.0500, 0.3500, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.52984536 12.17171284  8.58273015  8.35186252]]
# Cal C - shape (4, 1)
# C original [[ 9.879098 13.758751  7.738798  8.734636]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.05      ]
#  [0.34999999]
#  [0.25      ]]
# pred [[  6.83289807  -8.17571101 -11.63795975   8.4399274 ]]
# sum of pred -4.540845292909982
# pred [[-1.50476346  1.80048218  2.56295007 -1.85866878]]
# sum of pred 1.0000000000000002
# loss tensor(1.9817, dtype=torch.float64)
# 343
# x - C - mixture - Norm tensor([[8.8027, 6.0469, 6.2538, 5.7800]])
# y - B - ratio tensor([[0.1500, 0.0000, 0.8500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.46042247 10.01558386  7.04115615  6.11809719]]
# Cal C - shape (4, 1)
# C original [[8.802651 6.046852 6.253816 5.779997]]
# Cal B by Cal C
#  [[ 1.50000006e-01]
#  [ 3.55271368e-15]
#  [ 8.50000024e-01]
#  [-1.06581410e-14]]
# pred [[-5.90731965  8.02872834 11.15794496 -7.51368583]]
# sum of pred 5.765667822520193
# pred [[-1.02456816  1.39250623  1.93523895 -1.30317702]]
# sum of pred 1.0
# loss tensor(1.2389, dtype=torch.float64)
# 344
# x - C - mixture - Norm tensor([[14.5973, 14.4790, 14.3644, 12.5913]])
# y - B - ratio tensor([[0.1500, 0.1000, 0.3000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.21323378 14.00269247 10.87574448 10.97626069]]
# Cal C - shape (4, 1)
# C original [[14.59727  14.479035 14.364397 12.591282]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.1       ]
#  [0.30000001]
#  [0.44999999]]
# pred [[-3.24492422  3.06908702  6.21097135 -2.75010426]]
# sum of pred 3.285029895128723
# pred [[-0.98779138  0.93426456  1.89068944 -0.83716263]]
# sum of pred 0.9999999999999999
# loss tensor(1.2125, dtype=torch.float64)
# 345
# x - C - mixture - Norm tensor([[13.5161, 15.2691,  6.8030, 11.9312]])
# y - B - ratio tensor([[0.7000, 0.1000, 0.0000, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.20789429 11.72148686  7.19894826  7.2651007 ]]
# Cal C - shape (4, 1)
# C original [[13.516085  15.269125   6.8029847 11.931189 ]]
# Cal B by Cal C
#  [[0.69999999]
#  [0.1       ]
#  [0.        ]
#  [0.2       ]]
# pred [[ 5.15532603 -3.23439238 -9.00668805  4.95421427]]
# sum of pred -2.1315401283327304
# pred [[-2.41859206  1.5173969   4.22543678 -2.32424161]]
# sum of pred 1.0
# loss tensor(2.8214, dtype=torch.float64)
# 346
# x - C - mixture - Norm tensor([[ 7.1837, 11.0352,  7.5942,  8.8518]])
# y - B - ratio tensor([[0.1500, 0.3500, 0.4000, 0.1000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.85941084 11.34545231  8.22924299  8.43395471]]
# Cal C - shape (4, 1)
# C original [[ 7.1837263 11.035215   7.594217   8.851787 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.34999999]
#  [0.40000001]
#  [0.1       ]]
# pred [[  6.23339349  -8.15582575 -11.58527715   8.56850823]]
# sum of pred -4.939201174657228
# pred [[-1.26202462  1.65124389  2.3455771  -1.73479636]]
# sum of pred 1.0
# loss tensor(1.6234, dtype=torch.float64)
# 347
# x - C - mixture - Norm tensor([[18.7283, 13.5807, 10.0633, 11.7889]])
# y - B - ratio tensor([[0.1500, 0.4000, 0.2500, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.74125302 12.26909056  9.10984474  9.61831504]]
# Cal C - shape (4, 1)
# C original [[18.728327 13.580697 10.063254 11.78887 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.40000001]
#  [0.25      ]
#  [0.2       ]]
# pred [[ -9.07564466  14.6051132   17.66063827 -12.98444097]]
# sum of pred 10.205665840098092
# pred [[-0.88927511  1.43107891  1.73047389 -1.27227769]]
# sum of pred 1.0
# loss tensor(1.2558, dtype=torch.float64)
# 348
# x - C - mixture - Norm tensor([[ 9.4206, 11.9604, 10.1697, 10.9343]])
# y - B - ratio tensor([[0.4000, 0.3000, 0.0000, 0.3000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[12.35715297 12.92535324  9.10788073  9.68160095]]
# Cal C - shape (4, 1)
# C original [[ 9.420572  11.960353  10.1696825 10.934342 ]]
# Cal B by Cal C
#  [[0.40000001]
#  [0.30000001]
#  [0.        ]
#  [0.30000001]]
# pred [[ 3.03488844 -4.40629551 -6.00931458  4.99175186]]
# sum of pred -2.3889697776158485
# pred [[-1.2703754   1.84443334  2.51544186 -2.0894998 ]]
# sum of pred 1.0
# loss tensor(2.0299, dtype=torch.float64)
# 349
# x - C - mixture - Norm tensor([[ 9.1803, 10.4887, 12.1570,  4.5860]])
# y - B - ratio tensor([[0.2500, 0.2000, 0.5500, 0.0000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[ 9.80223904 10.26069989  6.95461701  6.65029842]]
# Cal C - shape (4, 1)
# C original [[ 9.180295  10.488673  12.156999   4.5860476]]
# Cal B by Cal C
#  [[0.25      ]
#  [0.2       ]
#  [0.55000001]
#  [0.        ]]
# pred [[-2.43289162 -0.65748182  6.33166067 -1.17306116]]
# sum of pred 2.0682260685265206
# pred [[-1.17631803 -0.3178965   3.0613968  -0.56718227]]
# sum of pred 1.0000000000000004
# loss tensor(1.2557, dtype=torch.float64)
# 350
# x - C - mixture - Norm tensor([[11.1963, 16.0734,  9.7093, 11.1370]])
# y - B - ratio tensor([[0.3000, 0.2500, 0.0000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.46738551 14.1672514  10.59219316 11.20881386]]
# Cal C - shape (4, 1)
# C original [[11.196251 16.073439  9.709275 11.137049]]
# Cal B by Cal C
#  [[3.00000012e-01]
#  [2.50000000e-01]
#  [7.10542736e-15]
#  [4.49999988e-01]]
# pred [[  8.33721444 -10.29427175 -14.68189669  10.71515991]]
# sum of pred -5.923794095423595
# pred [[-1.40741125  1.73778352  2.47846168 -1.80883396]]
# sum of pred 1.0
# loss tensor(1.9831, dtype=torch.float64)
# 351
# x - C - mixture - Norm tensor([[11.3149, 12.1824,  7.8298, 11.0683]])
# y - B - ratio tensor([[0.1500, 0.1000, 0.5500, 0.2000]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.22410657 11.8628601   8.80235945  8.48681763]]
# Cal C - shape (4, 1)
# C original [[11.31492   12.182364   7.8297954 11.068327 ]]
# Cal B by Cal C
#  [[0.15000001]
#  [0.1       ]
#  [0.55000001]
#  [0.2       ]]
# pred [[ 1.96417525 -0.78798162 -3.77888576  2.14479495]]
# sum of pred -0.457897179608473
# pred [[-4.28955524  1.72087021  8.25269498 -4.68400996]]
# sum of pred 0.9999999999999991
# loss tensor(4.6618, dtype=torch.float64)
# 352
# x - C - mixture - Norm tensor([[13.0378, 13.1654, 14.5995,  9.0169]])
# y - B - ratio tensor([[0.1000, 0.3500, 0.1000, 0.4500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[13.6456628  14.35406976 11.27774674 12.03024022]]
# Cal C - shape (4, 1)
# C original [[13.0378065 13.1654215 14.599453   9.0168705]]
# Cal B by Cal C
#  [[0.1       ]
#  [0.34999999]
#  [0.1       ]
#  [0.44999999]]
# pred [[-4.26529463  2.65069392  9.04813424 -3.5596818 ]]
# sum of pred 3.873851721291839
# pred [[-1.10104747  0.68425281  2.33569452 -0.91889986]]
# sum of pred 1.0000000000000002
# loss tensor(1.2850, dtype=torch.float64)
# 353
# x - C - mixture - Norm tensor([[12.1295, 12.6855,  9.3672,  9.6875]])
# y - B - ratio tensor([[0.3500, 0.3000, 0.1000, 0.2500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[11.96080099 12.51023848  8.83896809  9.29477721]]
# Cal C - shape (4, 1)
# C original [[12.129469 12.685457  9.367174  9.687538]]
# Cal B by Cal C
#  [[0.34999999]
#  [0.30000001]
#  [0.1       ]
#  [0.25      ]]
# pred [[0.14075425 0.38699481 0.38947068 0.15987083]]
# sum of pred 1.0770905786036877
# pred [[0.13068005 0.35929644 0.36159511 0.1484284 ]]
# sum of pred 1.0
# loss tensor(0.1604, dtype=torch.float64)
# 354
# x - C - mixture - Norm tensor([[10.4747, 10.4874,  5.3521,  4.0113]])
# y - B - ratio tensor([[0.5000, 0.4500, 0.0000, 0.0500]])
# A - shape (4, 4)
# B - shape (4, 1)
# C - shape (4, 1)
# Cal C
#  [[10.6236506  10.96293115  6.89670845  7.53577559]]
# Cal C - shape (4, 1)
# C original [[10.474734  10.487405   5.3520603  4.011294 ]]
# Cal B by Cal C
#  [[0.5       ]
#  [0.44999999]
#  [0.        ]
#  [0.05      ]]
# pred [[-0.01424363  1.05437828  2.26839414 -1.30058513]]
# sum of pred 2.0079436564891004
# pred [[-0.00709364  0.52510352  1.12971006 -0.64771993]]
# sum of pred 1.0
# loss tensor(0.6024, dtype=torch.float64)
# diff_list [[-0.60028954  1.37158605  0.91699356 -1.68829009]
#  [-1.93949805  1.38915197  2.9193104  -2.36896435]
#  [-1.16169983  1.56743293  0.87653141 -1.28226451]
#  ...
#  [-1.20104747  0.33425281  2.23569452 -1.36889985]
#  [-0.21931995  0.05929643  0.26159511 -0.1015716 ]
#  [-0.50709364  0.07510353  1.12971006 -0.69771994]]
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[11], line 127
#     123 # Check if the file "loss.pkl" already exists
#     124 if os.path.isfile(output_file_name):
#     125
#     126     # If the file exists, load the existing DataFrame from the file
# --> 127     df_existing = pd.read_csv(output_file_name)
#     129     # Open the file in binary mode
#     130     with open(output_file_name, 'w') as f:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nn/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nn/lib/python3.9/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nn/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nn/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1896, in TextFileReader._make_engine(self, f, engine)
#    1893     raise ValueError(msg)
#    1895 try:
# -> 1896     return mapping[engine](f, **self.options)
#    1897 except Exception:
#    1898     if self.handles is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nn/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file
